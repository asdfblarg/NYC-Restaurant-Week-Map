# %%
import folium
import pandas as pd
import numpy as np

# %%
rw_resturants_df = pd.read_excel("rw_resturants_2025-01.xlsx")
rw_resturants_df = rw_resturants_df.replace(np.nan, "")
rw_resturants_df
# Out:
#                          id  \
# 0    384ez4K7rUv5kkYWv8bpc1
# 1    7nexr1wJ2yVoEid0NuFUQO
# 2    3jdGxImRoczOD5HCrOQixj
# 3     4AMUemsb3LUNyOI1tMJxP
# 4     h7AKwFJyv3CkQeBxanlMV
# ..                      ...
# 606   YbI2QeLPJGO4ZMNNGd3Cb
# 607  2Bb8N4UObOESut2rZS1Bop
# 608  5Yo2enaJVHedAgbMP3ZfZA
# 609  5Jf2sf9XXbSlneZ1R7GciT
# 610  6COlOc8p0qBfXQHGvOenLv
#
#                                                  title  \
# 0    48212 - Restaurant Week - Program Participants...
# 1    40844 - Restaurant Week - Program Participants...
# 2    46310 - Restaurant Week - Program Participants...
# 3    49070 - Restaurant Week - Program Participants...
# 4    49423 - Restaurant Week - Program Participants...
# ..                                                 ...
# 606  44886 - Restaurant Week - Program Participants...
# 607  44761 - Restaurant Week - Program Participants...
# 608  32478 - Restaurant Week - Program Participants...
# 609  33662 - Restaurant Week - Program Participants...
# 610  33804 - Restaurant Week - Program Participants...
#
#                                                   name  \
# 0                                        Le Rock Venue
# 1                                     Frenchette Venue
# 2                                 Enoteca Harlem Venue
# 3                                       Artesano Venue
# 4                            Aitana Cocina & Bar Venue
# ..                                                 ...
# 606                          Nocciola Ristorante Venue
# 607  TsuruTonTan Udon Noodle Brasserie - Union Squa...
# 608                 Benoit Restaurant & Wine Bar Venue
# 609                                        Amali Venue
# 610                                    Scarpetta Venue
#
#                                                pdf_url  \
# 0
# 1    https://nyc-tourism-public.s3.amazonaws.com/wr...
# 2
# 3
# 4    https://nyc-tourism-public.s3.amazonaws.com/wr...
# ..                                                 ...
# 606
# 607  https://nyc-tourism-public.s3.amazonaws.com/wr...
# 608
# 609  https://nyc-tourism-public.s3.amazonaws.com/wr...
# 610
#
#                                              meal_type  \
# 0                      Lunch_Price_45; Dinner_Price_60
# 1                      Lunch_Price_45; Dinner_Price_60
# 2    Dinner_Price_60; Sunday_LunchBrunch_Price_45; ...
# 3          Lunch_Price_45; Sunday_LunchBrunch_Price_45
# 4    Lunch_Price_30; Dinner_Price_60; Sunday_LunchB...
# ..                                                 ...
# 606                  Dinner_Price_45; Sunday_Dinner_45
# 607                    Lunch_Price_30; Dinner_Price_45
# 608                    Lunch_Price_45; Dinner_Price_60
# 609            Dinner_Price_60; Sunday_Dinner_Price_60
# 610  Lunch_Price_45; Dinner_Price_60; Sunday_LunchB...
#
#                                            url_slug  \
# 0                                           le-rock
# 1                                        frenchette
# 2                                    enoteca-harlem
# 3                                          artesano
# 4                             aitana-cocina-and-bar
# ..                                              ...
# 606                             nocciola-ristorante
# 607  tsurutontan-udon-noodle-brasserie-union-square
# 608                      benoit-restaurant-wine-bar
# 609                                           amali
# 610                                       scarpetta
#
#                                                    url  \
# 0    https://www.nyctourism.com/restaurant-week/le-...
# 1    https://www.nyctourism.com/restaurant-week/fre...
# 2    https://www.nyctourism.com/restaurant-week/eno...
# 3    https://www.nyctourism.com/restaurant-week/art...
# 4    https://www.nyctourism.com/restaurant-week/ait...
# ..                                                 ...
# 606  https://www.nyctourism.com/restaurant-week/noc...
# 607  https://www.nyctourism.com/restaurant-week/tsu...
# 608  https://www.nyctourism.com/restaurant-week/ben...
# 609   https://www.nyctourism.com/restaurant-week/amali
# 610  https://www.nyctourism.com/restaurant-week/sca...
#
#                                                summary  \
# 0    Le Rock is a bustling French Brasserie that se...
# 1    This classic French brasserie and bar in Tribe...
# 2    Enoteca Harlem was born from a journey to the ...
# 3    With just one bite, Artesano transports diners...
# 4    Aitana is born from a passion for culinary exp...
# ..                                                 ...
# 606  Nocciola blends classic and modern Italian dis...
# 607          Japanese udon specialist in Union Square.
# 608  There were high expectations for this Midtown ...
# 609  Chef Alex Tubero's updated Mediterranean menu ...
# 610  It all started in a Greek revival townhouse on...
#
#                                                website  \
# 0                            https://www.lerocknyc.com
# 1                        https://www.frenchettenyc.com
# 2                        https://www.enotecaharlem.com
# 3                       https://artesanorestaurant.com
# 4                            https://www.aitananyc.com
# ..                                                 ...
# 606                            https://nocciolanyc.com
# 607           https://www.tsurutontan.com/union-square
# 608                           https://www.benoitny.com
# 609                           https://www.amalinyc.com
# 610  https://www.scarpettarestaurants.com/location/...
#
#                                           venueAddress   latitude  longitude  \
# 0              45 Rockefeller Plaza,Manhattan,10011,NY  40.759152 -73.977714
# 1                 241 West Broadway,Manhattan,10013,NY  40.719616 -74.005665
# 2     2220 Frederick Douglass Blvd.,Manhattan,10026,NY  40.806665 -73.953412
# 3                   90 Chambers St.,Manhattan,10007,NY  40.714477 -74.007437
# 4    Virgin Hotels New York City, 1227 Broadway, 4t...  40.746606 -73.988791
# ..                                                 ...        ...        ...
# 606                237 E. 116th St.,Manhattan,10029,NY  40.797504 -73.938382
# 607                  21 E. 16th St.,Manhattan,10003,NY  40.736872 -73.991269
# 608                  60 W. 55th St.,Manhattan,10019,NY  40.762483 -73.977340
# 609                 115 E. 60th St.,Manhattan,10022,NY  40.763374 -73.968571
# 610  The James New York—NoMad, 88 Madison Ave.,Manh...  40.744439 -73.985784
#
#                                                   tags  \
# 0    Restaurants; Midtown West; Manhattan; New York...
# 1    Restaurants; Tribeca; Manhattan; New York City...
# 2    Restaurants; Harlem; Manhattan; New York City;...
# 3    Restaurants; Tribeca; Manhattan; New York City...
# 4    Restaurants; Nomad; Manhattan; New York City; ...
# ..                                                 ...
# 606  Restaurants; East Harlem; Manhattan; New York ...
# 607  Restaurants; Union Square; Manhattan; New York...
# 608  Restaurants; Midtown West; Manhattan; New York...
# 609  Restaurants; Upper East Side; Manhattan; New Y...
# 610  Restaurants; Nomad; Manhattan; New York City; ...
#
#                                                img_url
# 0    http://images.ctfassets.net/1aemqu6a6t65/3h5Vd...
# 1    http://images.ctfassets.net/1aemqu6a6t65/5wS9P...
# 2                                                http:
# 3    http://images.ctfassets.net/1aemqu6a6t65/333sP...
# 4    http://images.ctfassets.net/1aemqu6a6t65/4f87Q...
# ..                                                 ...
# 606  http://images.ctfassets.net/1aemqu6a6t65/7crkS...
# 607  http://images.ctfassets.net/1aemqu6a6t65/79uas...
# 608  http://images.ctfassets.net/1aemqu6a6t65/5fZCj...
# 609  http://images.ctfassets.net/1aemqu6a6t65/6cpqL...
# 610  http://images.ctfassets.net/1aemqu6a6t65/4rYDi...
#
# [611 rows x 14 columns]

# %%
# m = folium.Map(location=[40.7396, -73.9739], zoom_start=12)
# m

# %%
m = folium.Map(location=[40.7396, -73.9739], zoom_start=12)
for index, rest in rw_resturants_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
        website_link = f'<a href="{rest.website}"target="_blank" style="font-size: 15px">Website</a></br>' if rest["website"] else ""
        pdf_link = f'<a href="{rest.pdf_url}"target="_blank" style="font-size: 15px">PDF</a></br>' if rest["pdf_url"] else ""
        
        tags = "; ".join(rest["tags"].split("; ")[4:]).replace("; ","</br><li>")
        if not rest["img_url"]:
            rest["img_url"] = "https://nyc-tourism-public.s3.amazonaws.com/programs/25WRW-HP-Hero02-1920x1280.jpg"
            
        popup_html = (
            f'<a href="{rest.url}"target="_blank" style="font-size: 20px">{rest["name"]}</a></br>'
            f'<a href="{rest.url}" target="_blank"><img src="{rest["img_url"]}" width="350"></a>'
            f'{website_link}'
            f'{pdf_link}'
            f'{rest["meal_type"].replace("; ","</br>")}</br></br>'
            f'<li>{tags}'
        )

        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=popup_html,
            max_width=350,
            lazy=True,
            # tooltip=tooltip,
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3813cb0dac5222a8b70f72563cbfe605 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3813cb0dac5222a8b70f72563cbfe605&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3813cb0dac5222a8b70f72563cbfe605 = L.map(
#                 &quot;map_3813cb0dac5222a8b70f72563cbfe605&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eec14db70c2915fbe64f2a378fd226cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eec14db70c2915fbe64f2a378fd226cf.addTo(map_3813cb0dac5222a8b70f72563cbfe605);
#
#
#             var marker_3cfeaa6e6435d825203a3dbf7d04107d = L.marker(
#                 [40.7591523, -73.9777136],
#                 {
#   &quot;maxWidth&quot;: 350,
#   &quot;lazy&quot;: true,
# }
#             ).addTo(map_3813cb0dac5222a8b70f72563cbfe605);
#
#
#         var popup_36e1abd9df95b4436e698014fcbe2443 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82456c0440edd5cb05e8f898bc0ad6e3 = $(`&lt;div id=&quot;html_82456c0440edd5cb05e8f898bc0ad6e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/le-rock&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Le Rock Venue&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/le-rock&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/3h5Vdf1tWquIFwhsew3750/faf588e74e2cef2159738897180e2d8a/Le-Rock-Midtown-Manhattan-NYC-Courtesy-03.jpg&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.lerocknyc.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;Lunch_Price_45&lt;/br&gt;Dinner_Price_60&lt;/br&gt;&lt;/br&gt;&lt;li&gt;Wheelchair Accessible&lt;/br&gt;&lt;li&gt;French&lt;/br&gt;&lt;li&gt;$$$$&lt;/br&gt;&lt;li&gt;Member Organization&lt;/div&gt;`)[0];
#                 popup_36e1abd9df95b4436e698014fcbe2443.setContent(html_82456c0440edd5cb05e8f898bc0ad6e3);
#
#
#
#         marker_3cfeaa6e6435d825203a3dbf7d04107d.bindPopup(popup_36e1abd9df95b4436e698014fcbe2443)
#         ;
#
#
#
#
#             var marker_8858fccb30bcf07bb41624322a699afc = L.marker(
#                 [40.7196161, -74.0056648],
#                 {
#   &quot;maxWidth&quot;: 350,
#   &quot;lazy&quot;: true,
# }
#             ).addTo(map_3813cb0dac5222a8b70f72563cbfe605);
#
#
#         var popup_7e384c5e7e5ac96bdd67bc2ecd7f5ebc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d436e57267090b1d430bd5a2d850d233 = $(`&lt;div id=&quot;html_d436e57267090b1d430bd5a2d850d233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/frenchette&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Frenchette Venue&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/frenchette&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/5wS9P9eqYek7BSSBcouIOq/aab812dc76defe8048c72cf515dfe1c7/interiors_details_186.jpg&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.frenchettenyc.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://nyc-tourism-public.s3.amazonaws.com/wrw25/menus/40844-Frenchette-menu.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Lunch_Price_45&lt;/br&gt;Dinner_Price_60&lt;/br&gt;&lt;/br&gt;&lt;li&gt;Wheelchair Accessible&lt;/br&gt;&lt;li&gt;French&lt;/br&gt;&lt;li&gt;Gluten-Free&lt;/br&gt;&lt;li&gt;Member Organization&lt;/br&gt;&lt;li&gt;$$$$$&lt;/div&gt;`)[0];
#                 popup_7e384c5e7e5ac96bdd67bc2ecd7f5ebc.setContent(html_d436e57267090b1d430bd5a2d850d233);
#
#
#
#         marker_8858fccb30bcf07bb41624322a699afc.bindPopup(popup_7e384c5e7e5ac96bdd67bc2ecd7f5ebc)
#         ;
#
#
#
#
#             var marker_d26151685a488bade044b940ea2661dc = L.marker(
#                 [40.8066646, -73.9534125],
#                 {
#   &quot;maxWidth&quot;: 350,
#   &quot;lazy&quot;: true,
# }
#             ).addTo(map_3813cb0dac5222a8b70f72563cbfe605);
#
#
#         var popup_56beea113f562afcd639db0697b318a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b39168f3baad046fe5dcdcc8b1910a03 = $(`&lt;div id=&quot;html_b39168f3baad046fe5dcdcc8b1910a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/rest

# %%
rw_resturants_filtered_df = rw_resturants_df[rw_resturants_df["meal_type"].str.contains("Lunch_Price_30")]
map_30 = folium.Map(location=[40.7396, -73.9739], zoom_start=12)

for index, rest in rw_resturants_filtered_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=f'<a href="{rest.url}"">{rest["name"]}</>',
        ).add_to(map_30)

map_30
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_258124239712e4fa094073792950f988 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_258124239712e4fa094073792950f988&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_258124239712e4fa094073792950f988 = L.map(
#                 &quot;map_258124239712e4fa094073792950f988&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_206c1acf483a6b79cd7c559c5969d747 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_206c1acf483a6b79cd7c559c5969d747.addTo(map_258124239712e4fa094073792950f988);
#
#
#             var marker_74bc0b413e02c84e411c207c1f4d9f19 = L.marker(
#                 [40.7466063, -73.988791],
#                 {
# }
#             ).addTo(map_258124239712e4fa094073792950f988);
#
#
#         var popup_509692297964ed6c8e06f1f4ea760ba7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2138b6c2f7865b4a83b6757d886bbce9 = $(`&lt;div id=&quot;html_2138b6c2f7865b4a83b6757d886bbce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/aitana-cocina-and-bar&quot;&quot;&gt;Aitana Cocina &amp; Bar Venue&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_509692297964ed6c8e06f1f4ea760ba7.setContent(html_2138b6c2f7865b4a83b6757d886bbce9);
#
#
#
#         marker_74bc0b413e02c84e411c207c1f4d9f19.bindPopup(popup_509692297964ed6c8e06f1f4ea760ba7)
#         ;
#
#
#
#
#             var marker_8f65ca1d2d7a2d338657786a8259d679 = L.marker(
#                 [40.759149, -73.984164],
#                 {
# }
#             ).addTo(map_258124239712e4fa094073792950f988);
#
#
#         var popup_0440b1f79317ff53673165129f1dc873 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4af22d6cdebd1ed0e3e9e2075c53a19e = $(`&lt;div id=&quot;html_4af22d6cdebd1ed0e3e9e2075c53a19e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/the-terrace-and-outdoor-gardens&quot;&quot;&gt;The Terrace and Outdoor Gardens Venue&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_0440b1f79317ff53673165129f1dc873.setContent(html_4af22d6cdebd1ed0e3e9e2075c53a19e);
#
#
#
#         marker_8f65ca1d2d7a2d338657786a8259d679.bindPopup(popup_0440b1f79317ff53673165129f1dc873)
#         ;
#
#
#
#
#             var marker_272e1fb82ca975f3f7fd091ceb7d43eb = L.marker(
#                 [40.7481812, -73.9403027],
#                 {
# }
#             ).addTo(map_258124239712e4fa094073792950f988);
#
#
#         var popup_6dd65f90a762ac88d6de813344da763d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92ac758b5d67bf6136e5e10b9a0fa093 = $(`&lt;div id=&quot;html_92ac758b5d67bf6136e5e10b9a0fa093&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/jing-li&quot;&quot;&gt;Jing Li Venue&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_6dd65f90a762ac88d6de813344da763d.setContent(html_92ac758b5d67bf6136e5e10b9a0fa093);
#
#
#
#         marker_272e1fb82ca975f3f7fd091ceb7d43eb.bindPopup(popup_6dd65f90a762ac88d6de813344da763d)
#         ;
#
#
#
#
#             var marker_47f4bc4835ac56b09ead3553e075ee2c = L.marker(
#                 [40.7323718, -73.8497752],
#                 {
# }
#             ).addTo(map_258124239712e4fa094073792950f988);
#
#
#         var popup_44a0d799700cbf4b120aa11bd7cbd64c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdb8ac882263ff33dbe918a0d0c90461 = $(`&lt;div id=&quot;html_cdb8ac882263ff33dbe918a0d0c90461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/mito-forest-hills&quot;&quot;&gt;Mito - Forest Hills Venue&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_44a0d799700cbf4b120aa11bd7cbd64c.setContent(html_cdb8ac882263ff33dbe918a0d0c90461);
#
#
#
#         marker_47f4bc4835ac56b09ead3553e075ee2c.bindPopup(popup_44a0d799700cbf4b120aa11bd7cbd64c)
#         ;
#
#
#
#
#             var marker_61dddc7f56755905689cf78f87b28ad5 = L.marker(
#                 [40.7581194, -73.9830293],
#                 {
# }
#             ).addTo(map_258124239712e4fa094073792950f988);
#
#
#         var popup_41cc0e39ee54ea13c177fcb4df6f69a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_894899f83665d30d1342ddc11ff131c5 = $(`&lt;div id=&quot;html_894899f83665d30d1342ddc11f

# %%
rw_resturants_filtered_df = rw_resturants_df[rw_resturants_df["meal_type"].str.contains(".+(?:30|45)")]
map_30 = folium.Map(location=[40.7396, -73.9739], zoom_start=12)

for index, rest in rw_resturants_filtered_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
#         folium.Marker(
#             [rest["latitude"], rest["longitude"]],
#             popup=f'<a href="{rest.url}"">{rest["name"]}</>',
#         ).add_to(map_30)
        
        website_link = f'<a href="{rest.website}"target="_blank" style="font-size: 15px">Website</a></br>' if rest["website"] else ""
        pdf_link = f'<a href="{rest.pdf_url}"target="_blank" style="font-size: 15px">PDF</a></br>' if rest["pdf_url"] else ""
        
        tags = "; ".join(rest["tags"].split("; ")[4:]).replace("; ","</br>")
        
        popup_html = (
            f'<a href="{rest.url}"target="_blank" style="font-size: 20px">{rest["name"]}</a></br>'
            f'<a href="{rest.url}" target="_blank"><img src="{rest["img_url"]}" width="350"></a>'
            f'{website_link}'
            f'{pdf_link}'
            f'{rest["meal_type"].replace("; ","</br>")}</br>'
#             f'{tags}'
        )

        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=popup_html,
            max_width=350,
            lazy=True,
            # tooltip=tooltip,
        ).add_to(map_30)

map_30
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16a0c26c04f59c40683d211a1c219737 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16a0c26c04f59c40683d211a1c219737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16a0c26c04f59c40683d211a1c219737 = L.map(
#                 &quot;map_16a0c26c04f59c40683d211a1c219737&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ae5b9f43224a8b520d2adabb402cdbc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#             var marker_514a08558d66643281aac27e931bba40 = L.marker(
#                 [40.7031277, -74.0083191],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_ad34678eaebab2d36679963b28ca66df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb81bc42a24c9d20eaa90775ae72b156 = $(`&lt;div id=&quot;html_bb81bc42a24c9d20eaa90775ae72b156&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Industry Kitchen&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/6FzOkiZTXLxpZbxUw7NNJU/995d8bdc49579b2ecf7e158cf07e67aa/industry-kitchen-courtesy-industry-kitchen&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.industry-kitchen.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/4Z222dcc9tOVNE9TQnct4L/68db5953862f6f9823f8193289d38a09/Induskit_Restaurant_Week_Summer_2023-14-.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Lunch_Price_45&lt;/br&gt;Dinner_Price_60&lt;/br&gt;Sunday_Dinner_Price_45&lt;/br&gt;&lt;/div&gt;`)[0];
#                 popup_ad34678eaebab2d36679963b28ca66df.setContent(html_bb81bc42a24c9d20eaa90775ae72b156);
#
#
#
#         marker_514a08558d66643281aac27e931bba40.bindPopup(popup_ad34678eaebab2d36679963b28ca66df)
#         ;
#
#
#
#
#             var marker_ccd2c3bca6aa18a58722dbf67c70b3c5 = L.marker(
#                 [40.7423311, -74.0034791],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_e6ba8bd382c17eb3c4910da7c36315d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9631308a8a739e37d39be5d0e3606f0b = $(`&lt;div id=&quot;html_9631308a8a739e37d39be5d0e3606f0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/philippe-by-philippe-chow-downtown&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Philippe by Philippe Chow Downtown&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/philippe-by-philippe-chow-downtown&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/4wWLgC5583jEaCl2qMIdox/15d251dbfc08c67d0eb8dff123802658/philippe-chow-downtown-chelsea-manhattan-nyc-philippe-chow-nyc-downtown---private-dining---6016&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://philippechow.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/5nxNf0lU8Mu08saJgvoCv2/c939c4824b14f228d55d09a33b4b19dc/Philippe_NYC_Summer_Restaurant_Week_2023_8.5x11_-_UES-29-.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Dinner_Price_45&lt;/br&gt;Sunday_Dinner_Price_45&lt;/br&gt;&lt;/div&gt;`)[0];
#                 popup_e6ba8bd382c17eb3c4910da7c36315d4.setContent(html_9631308a8a739e37d39be5d0e3606f0b);
#
#
#
#         marker_ccd2c3bca6aa18a58722dbf67c70b3c5.bindPopup(popup_e6ba8bd382c17eb3c4910da7c36315d4)
#         ;
#
#
#
#
#             var marker_d5c8423b85411aa592b5c756785acb01 = L.marker(
#                 [40.7518063, -73.9910432],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_dc395b981552e64d97ff4211fcdce43b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
