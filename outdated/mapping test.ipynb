# %%
import folium
import pandas as pd
import numpy as np

# %%
rw_resturants_df = pd.read_excel("rw_resturants_v2.xlsx")
rw_resturants_df = rw_resturants_df.replace(np.nan, "")
rw_resturants_df
# Out:
#                                    name                            url_slug  \
# 0                             Riverpark                           riverpark
# 1                      Industry Kitchen                    industry-kitchen
# 2    Philippe by Philippe Chow Downtown  philippe-by-philippe-chow-downtown
# 3                                 Versa                               versa
# 4                            Sagaponack                          sagaponack
# ..                                  ...                                 ...
# 546    Treadwell Park - Upper East Side      treadwell-park-upper-east-side
# 547   Flor de Mayo - Washington Heights     flor-de-mayo-washington-heights
# 548                The Russian Tea Room                the-russian-tea-room
# 549            Au Jus - Upper West Side              au-jus-upper-west-side
# 550                       Barbalu Bklyn                       barbalu-bklyn
#
#                                                    url  \
# 0    https://www.nyctourism.com/restaurant-week/riv...
# 1    https://www.nyctourism.com/restaurant-week/ind...
# 2    https://www.nyctourism.com/restaurant-week/phi...
# 3     https://www.nyctourism.com/restaurant-week/versa
# 4    https://www.nyctourism.com/restaurant-week/sag...
# ..                                                 ...
# 546  https://www.nyctourism.com/restaurant-week/tre...
# 547  https://www.nyctourism.com/restaurant-week/flo...
# 548  https://www.nyctourism.com/restaurant-week/the...
# 549  https://www.nyctourism.com/restaurant-week/au-...
# 550  https://www.nyctourism.com/restaurant-week/bar...
#
#                                                img_url  \
# 0    http://images.ctfassets.net/1aemqu6a6t65/5chjr...
# 1    http://images.ctfassets.net/1aemqu6a6t65/6FzOk...
# 2    http://images.ctfassets.net/1aemqu6a6t65/4wWLg...
# 3    http://images.ctfassets.net/1aemqu6a6t65/5zb3q...
# 4    http://images.ctfassets.net/1aemqu6a6t65/6mhnn...
# ..                                                 ...
# 546  http://images.ctfassets.net/1aemqu6a6t65/vkgDk...
# 547  http://images.ctfassets.net/1aemqu6a6t65/vkgDk...
# 548  http://images.ctfassets.net/1aemqu6a6t65/5ngPy...
# 549  http://images.ctfassets.net/1aemqu6a6t65/5ngPy...
# 550  http://images.ctfassets.net/1aemqu6a6t65/5yWme...
#
#                                                pdf_url  \
# 0    https://assets.ctfassets.net/1aemqu6a6t65/q6E5...
# 1    https://assets.ctfassets.net/1aemqu6a6t65/4Z22...
# 2    https://assets.ctfassets.net/1aemqu6a6t65/5nxN...
# 3    https://assets.ctfassets.net/1aemqu6a6t65/71Dh...
# 4    https://assets.ctfassets.net/1aemqu6a6t65/4Pev...
# ..                                                 ...
# 546  https://assets.ctfassets.net/1aemqu6a6t65/1co0...
# 547  https://assets.ctfassets.net/1aemqu6a6t65/Qh7F...
# 548  https://assets.ctfassets.net/1aemqu6a6t65/mGgY...
# 549
# 550  https://assets.ctfassets.net/1aemqu6a6t65/5saH...
#
#                                                website  \
# 0                         https://www.riverparknyc.com
# 1                     https://www.industry-kitchen.com
# 2                             https://philippechow.com
# 3                                 https://versanyc.com
# 4                          https://www.saganewyork.com
# ..                                                 ...
# 546  https://www.treadwellpark.com/location/upper-e...
# 547                         https://www.flordemayo.com
# 548                      https://russiantearoomnyc.com
# 549
# 550                             http://www.barbalu.com
#
#                                                   tags  \
# 0    Restaurants; Kips Bay; Manhattan; New York Cit...
# 1    Restaurants; Lower Manhattan; Manhattan; New Y...
# 2    Restaurants; Chelsea; Manhattan; New York City...
# 3    Restaurants; Garment District; Manhattan; New ...
# 4    Restaurants; Flatiron District; Manhattan; New...
# ..                                                 ...
# 546  Nightlife; Upper East Side; Manhattan; New Yor...
# 547  Restaurants; Washington Heights; Manhattan; Ne...
# 548  Restaurants; Midtown West; Manhattan; New York...
# 549  Restaurants; Upper West Side; Manhattan; New Y...
# 550  Restaurants; Boerum Hill; Brooklyn; New York C...
#
#                                              meal_type  \
# 0                                      Dinner_Price_60
# 1    Lunch_Price_45; Dinner_Price_60; Sunday_Dinner...
# 2              Dinner_Price_45; Sunday_Dinner_Price_45
# 3                      Lunch_Price_30; Dinner_Price_45
# 4    Lunch_Price_30; Dinner_Price_45; Sunday_LunchB...
# ..                                                 ...
# 546                                    Dinner_Price_45
# 547                  Dinner_Price_45; Sunday_Dinner_45
# 548  Lunch_Price_30; Dinner_Price_45; Sunday_LunchB...
# 549  Lunch_Price_30; Dinner_Price_45; Sunday_LunchB...
# 550                    Lunch_Price_30; Dinner_Price_45
#
#                                                address   latitude  longitude
# 0    Alexandria Center, 450 E. 29th St.,Manhattan,1...    40.7396   -73.9739
# 1                      70 South St.,Manhattan,10038,NY  40.703128 -74.008319
# 2    Dream Downtown, 355 W. 16th St.,Manhattan,1001...  40.742331 -74.003479
# 3                   218 W. 35th St.,Manhattan,10001,NY  40.751806 -73.991043
# 4                     4 W. 22nd St.,Manhattan,10010,NY  40.740936 -73.990785
# ..                                                 ...        ...        ...
# 546                 1125 First Ave.,Manhattan,10065,NY  40.761474 -73.961107
# 547                   4160 Broadway,Manhattan,10033,NY  40.847029 -73.937888
# 548                 150 W. 57th St.,Manhattan,10019,NY  40.764948 -73.979434
# 549                   2621 Broadway,Manhattan,10025,NY  40.796848 -73.970592
# 550                    68 Bergen St.,Brooklyn,11201,NY  40.686744 -73.991015
#
# [551 rows x 11 columns]

# %%
# m = folium.Map(location=[40.7396, -73.9739], zoom_start=12)
# m

# %%
m = folium.Map(location=[40.7396, -73.9739], zoom_start=12)
for index, rest in rw_resturants_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
        website_link = f'<a href="{rest.website}"target="_blank" style="font-size: 15px">Website</a></br>' if rest["website"] else ""
        pdf_link = f'<a href="{rest.pdf_url}"target="_blank" style="font-size: 15px">PDF</a></br>' if rest["pdf_url"] else ""
        
        tags = "; ".join(rest["tags"].split("; ")[4:]).replace("; ","</br>")
        
        popup_html = (
            f'<a href="{rest.url}"target="_blank" style="font-size: 20px">{rest["name"]}</a></br>'
            f'<a href="{rest.url}" target="_blank"><img src="{rest["img_url"]}" width="350"></a>'
            f'{website_link}'
            f'{pdf_link}'
            f'{rest["meal_type"].replace("; ","</br>")}</br>'
            f'{tags}'
        )

        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=popup_html,
            max_width=350,
            lazy=True,
            # tooltip=tooltip,
        ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22da589ec891ffe698aee553f093f516 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22da589ec891ffe698aee553f093f516&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22da589ec891ffe698aee553f093f516 = L.map(
#                 &quot;map_22da589ec891ffe698aee553f093f516&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d61fd2d3f97ea48bf259211526480049 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_22da589ec891ffe698aee553f093f516);
#
#
#             var marker_969956a35de2dc4aacb5bc4785696044 = L.marker(
#                 [40.7396, -73.9739],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_22da589ec891ffe698aee553f093f516);
#
#
#         var popup_99103990caba50f85bf8b06349e010b5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_83e83b8be9153092e4dceceafd0be276 = $(`&lt;div id=&quot;html_83e83b8be9153092e4dceceafd0be276&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/riverpark&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Riverpark&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/riverpark&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/5chjrjy8X94yv4ERx3xJvv/a6b25f13b50f95926e5e688bdbb7228f/victoria-segal---1_24_13-cauliflower-soup&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.riverparknyc.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/q6E5j4yRstJppHgH6sNEK/a7308a410f5dfac7e31bc1d2d67ce4eb/Riverpark_Restaurant_Week_Summer_2023_Menu.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Dinner_Price_60&lt;/br&gt;Mastercard Offer&lt;/br&gt;Large Print&lt;/br&gt;Wheelchair Accessible&lt;/br&gt;American (New)&lt;/br&gt;Vegetarian Options&lt;/br&gt;Gluten-Free&lt;/br&gt;Free WiFi&lt;/br&gt;Internet&lt;/br&gt;$$$&lt;/br&gt;Maritime/Waterfront&lt;/br&gt;Member Organization&lt;/br&gt;Private Function Room(s)&lt;/br&gt;Luxury&lt;/div&gt;`)[0];
#                 popup_99103990caba50f85bf8b06349e010b5.setContent(html_83e83b8be9153092e4dceceafd0be276);
#
#
#
#         marker_969956a35de2dc4aacb5bc4785696044.bindPopup(popup_99103990caba50f85bf8b06349e010b5)
#         ;
#
#
#
#
#             var marker_bd81063ce4e656e258a5e4747fffd3b0 = L.marker(
#                 [40.7031277, -74.0083191],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_22da589ec891ffe698aee553f093f516);
#
#
#         var popup_b1be7cd166b2e09c41f19ed3a82ff846 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8a16b60813e43dea5be1d832c21f2210 = $(`&lt;div id=&quot;html_8a16b60813e43dea5be1d832c21f2210&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Industry Kitchen&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/6FzOkiZTXLxpZbxUw7NNJU/995d8bdc49579b2ecf7e158cf07e67aa/industry-kitchen-courtesy-industry-kitchen&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.industry-kitchen.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/4Z222dcc9tOVNE9TQnct4L/68db5953862f6f9823f8193289d38a09/Induskit_Restaurant_Week_Summer_2023-14-.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Lunch_Price_45&lt;/br&gt;Dinner_Price_60&lt;/br&gt;Sunday_Dinner_Price_45&lt;/br&gt;Mastercard Offer&lt;/br&gt;Wheelchair Accessible&lt;/br&gt;American (New)&lt;/br&gt;Vegetarian Options&lt;/br&gt;Vegan Options&lt;/br&gt;Gluten-Free&lt;/br&gt;$$$$&lt;/br&gt;Member Organization&lt;/br&gt;Outdoor Dining&lt;/div&gt;`)[0];
#                 popup_b1be7cd166b2e09c41f19ed3a82ff846.setContent(html_8a16b60813e43dea5be1d832c21f2210);
#
#
#
#         marker_bd81063ce4e656e258a5e4747fffd3b0.bindPopup(popup_b1be7cd166b2e09c41f19ed3a82ff846)
#         ;
#
#
#
#
#             var marker_e86d83d7f31e

# %%
rw_resturants_filtered_df = rw_resturants_df[rw_resturants_df["meal_type"].str.contains("Lunch_Price_30")]
map_30 = folium.Map(location=[40.7396, -73.9739], zoom_start=12)

for index, rest in rw_resturants_filtered_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=f'<a href="{rest.url}"">{rest["name"]}</>',
        ).add_to(map_30)

map_30
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3766c10e4b72a651a44cbda15096f0b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3766c10e4b72a651a44cbda15096f0b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3766c10e4b72a651a44cbda15096f0b3 = L.map(
#                 &quot;map_3766c10e4b72a651a44cbda15096f0b3&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ece968940017ad3e4a8a732c18051019 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#             var marker_0065958f5da3332092e9aa3798c43518 = L.marker(
#                 [40.7518063, -73.9910432],
#                 {}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#         var popup_8362734d89946d007d7898b482ceea4b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_98fa263152e85c53b4b7618283733ded = $(`&lt;div id=&quot;html_98fa263152e85c53b4b7618283733ded&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/versa&quot;&quot;&gt;Versa&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_8362734d89946d007d7898b482ceea4b.setContent(html_98fa263152e85c53b4b7618283733ded);
#
#
#
#         marker_0065958f5da3332092e9aa3798c43518.bindPopup(popup_8362734d89946d007d7898b482ceea4b)
#         ;
#
#
#
#
#             var marker_7bfa269a93bb71e2fb10f901f66d8cac = L.marker(
#                 [40.7409362, -73.9907851],
#                 {}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#         var popup_75b3aef95e4423b04946170c0305550a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4ea65952483c0508b5f182ead79de46 = $(`&lt;div id=&quot;html_b4ea65952483c0508b5f182ead79de46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/sagaponack&quot;&quot;&gt;Sagaponack&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_75b3aef95e4423b04946170c0305550a.setContent(html_b4ea65952483c0508b5f182ead79de46);
#
#
#
#         marker_7bfa269a93bb71e2fb10f901f66d8cac.bindPopup(popup_75b3aef95e4423b04946170c0305550a)
#         ;
#
#
#
#
#             var marker_ac6166c9d05d11722dbb1406b96a115f = L.marker(
#                 [40.7870473, -73.9781361],
#                 {}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#         var popup_d78003a0eea2af0a63a242319865518a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_955253f6ee9f2b01bc6467636c056cca = $(`&lt;div id=&quot;html_955253f6ee9f2b01bc6467636c056cca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/5-napkin-burger-upper-west-side&quot;&quot;&gt;5 Napkin Burger - Upper West Side&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_d78003a0eea2af0a63a242319865518a.setContent(html_955253f6ee9f2b01bc6467636c056cca);
#
#
#
#         marker_ac6166c9d05d11722dbb1406b96a115f.bindPopup(popup_d78003a0eea2af0a63a242319865518a)
#         ;
#
#
#
#
#             var marker_015e3e726f67a0331abc4eaab60c0af9 = L.marker(
#                 [40.759987, -73.9912338],
#                 {}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#         var popup_1f80804f3edfb31a6b055be83eb81686 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c496c3fa7aab1b41ca56899a3efe39b7 = $(`&lt;div id=&quot;html_c496c3fa7aab1b41ca56899a3efe39b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/five-napkin-burger-hells-kitchen&quot;&quot;&gt;5 Napkin Burger - Hell&#x27;s Kitchen&lt;/&gt;&lt;/div&gt;`)[0];
#                 popup_1f80804f3edfb31a6b055be83eb81686.setContent(html_c496c3fa7aab1b41ca56899a3efe39b7);
#
#
#
#         marker_015e3e726f67a0331abc4eaab60c0af9.bindPopup(popup_1f80804f3edfb31a6b055be83eb81686)
#         ;
#
#
#
#
#             var marker_1a6d963d2e368709e8bfb87bc1c9dda8 = L.marker(
#                 [40.779347, -73.9776056],
#                 {}
#             ).addTo(map_3766c10e4b72a651a44cbda15096f0b3);
#
#
#         var popup_bb6916c5b61974ebcd8f09f361ba5c76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1a7919917e67db3266720612ecf81323 = $(`&lt;div id=&quot;html_1a7919917e67db3266720612ecf81323&quot; styl

# %%
rw_resturants_filtered_df = rw_resturants_df[rw_resturants_df["meal_type"].str.contains(".+(?:30|45)")]
map_30 = folium.Map(location=[40.7396, -73.9739], zoom_start=12)

for index, rest in rw_resturants_filtered_df.iterrows():
    if rest["latitude"] and rest["longitude"]:
        
#         folium.Marker(
#             [rest["latitude"], rest["longitude"]],
#             popup=f'<a href="{rest.url}"">{rest["name"]}</>',
#         ).add_to(map_30)
        
        website_link = f'<a href="{rest.website}"target="_blank" style="font-size: 15px">Website</a></br>' if rest["website"] else ""
        pdf_link = f'<a href="{rest.pdf_url}"target="_blank" style="font-size: 15px">PDF</a></br>' if rest["pdf_url"] else ""
        
        tags = "; ".join(rest["tags"].split("; ")[4:]).replace("; ","</br>")
        
        popup_html = (
            f'<a href="{rest.url}"target="_blank" style="font-size: 20px">{rest["name"]}</a></br>'
            f'<a href="{rest.url}" target="_blank"><img src="{rest["img_url"]}" width="350"></a>'
            f'{website_link}'
            f'{pdf_link}'
            f'{rest["meal_type"].replace("; ","</br>")}</br>'
#             f'{tags}'
        )

        folium.Marker(
            [rest["latitude"], rest["longitude"]],
            popup=popup_html,
            max_width=350,
            lazy=True,
            # tooltip=tooltip,
        ).add_to(map_30)

map_30
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16a0c26c04f59c40683d211a1c219737 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16a0c26c04f59c40683d211a1c219737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16a0c26c04f59c40683d211a1c219737 = L.map(
#                 &quot;map_16a0c26c04f59c40683d211a1c219737&quot;,
#                 {
#                     center: [40.7396, -73.9739],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ae5b9f43224a8b520d2adabb402cdbc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#             var marker_514a08558d66643281aac27e931bba40 = L.marker(
#                 [40.7031277, -74.0083191],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_ad34678eaebab2d36679963b28ca66df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bb81bc42a24c9d20eaa90775ae72b156 = $(`&lt;div id=&quot;html_bb81bc42a24c9d20eaa90775ae72b156&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Industry Kitchen&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/industry-kitchen&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/6FzOkiZTXLxpZbxUw7NNJU/995d8bdc49579b2ecf7e158cf07e67aa/industry-kitchen-courtesy-industry-kitchen&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://www.industry-kitchen.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/4Z222dcc9tOVNE9TQnct4L/68db5953862f6f9823f8193289d38a09/Induskit_Restaurant_Week_Summer_2023-14-.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Lunch_Price_45&lt;/br&gt;Dinner_Price_60&lt;/br&gt;Sunday_Dinner_Price_45&lt;/br&gt;&lt;/div&gt;`)[0];
#                 popup_ad34678eaebab2d36679963b28ca66df.setContent(html_bb81bc42a24c9d20eaa90775ae72b156);
#
#
#
#         marker_514a08558d66643281aac27e931bba40.bindPopup(popup_ad34678eaebab2d36679963b28ca66df)
#         ;
#
#
#
#
#             var marker_ccd2c3bca6aa18a58722dbf67c70b3c5 = L.marker(
#                 [40.7423311, -74.0034791],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_e6ba8bd382c17eb3c4910da7c36315d4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9631308a8a739e37d39be5d0e3606f0b = $(`&lt;div id=&quot;html_9631308a8a739e37d39be5d0e3606f0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/philippe-by-philippe-chow-downtown&quot;target=&quot;_blank&quot; style=&quot;font-size: 20px&quot;&gt;Philippe by Philippe Chow Downtown&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://www.nyctourism.com/restaurant-week/philippe-by-philippe-chow-downtown&quot; target=&quot;_blank&quot;&gt;&lt;img src=&quot;http://images.ctfassets.net/1aemqu6a6t65/4wWLgC5583jEaCl2qMIdox/15d251dbfc08c67d0eb8dff123802658/philippe-chow-downtown-chelsea-manhattan-nyc-philippe-chow-nyc-downtown---private-dining---6016&quot; width=&quot;350&quot;&gt;&lt;/a&gt;&lt;a href=&quot;https://philippechow.com&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;Website&lt;/a&gt;&lt;/br&gt;&lt;a href=&quot;https://assets.ctfassets.net/1aemqu6a6t65/5nxNf0lU8Mu08saJgvoCv2/c939c4824b14f228d55d09a33b4b19dc/Philippe_NYC_Summer_Restaurant_Week_2023_8.5x11_-_UES-29-.pdf&quot;target=&quot;_blank&quot; style=&quot;font-size: 15px&quot;&gt;PDF&lt;/a&gt;&lt;/br&gt;Dinner_Price_45&lt;/br&gt;Sunday_Dinner_Price_45&lt;/br&gt;&lt;/div&gt;`)[0];
#                 popup_e6ba8bd382c17eb3c4910da7c36315d4.setContent(html_9631308a8a739e37d39be5d0e3606f0b);
#
#
#
#         marker_ccd2c3bca6aa18a58722dbf67c70b3c5.bindPopup(popup_e6ba8bd382c17eb3c4910da7c36315d4)
#         ;
#
#
#
#
#             var marker_d5c8423b85411aa592b5c756785acb01 = L.marker(
#                 [40.7518063, -73.9910432],
#                 {&quot;lazy&quot;: true, &quot;maxWidth&quot;: 350}
#             ).addTo(map_16a0c26c04f59c40683d211a1c219737);
#
#
#         var popup_dc395b981552e64d97ff4211fcdce43b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
