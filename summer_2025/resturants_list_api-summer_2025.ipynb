# %%
import pandas as pd
import requests

# %%
BASE_URL = "https://program-api.nyctourism.com/restaurant-week"
HEADERS = {"x-api-key": "lTQSe929f34fohKaNq0OH53mdVL0yncvtqmuUG6i"}

# %%
def make_request(page=1, lookup={}):
    payload = {
        "page": page,
        "lookup": lookup
    }
    response = requests.post(BASE_URL, headers=HEADERS, json=payload)
    return response.json()

# %%
# %%time
count = 0
page = 1
items = []

while True:
    print(f"Page {page}:", end="")
    res_json = make_request(page)
    items += res_json["items"]
    count += len(res_json["items"])
    page += 1
    print(f" {count} out of {res_json["count"]}")
    if count >= res_json["count"]:
        break
        
lookup = res_json["lookup"]
# Out:
# Page 1: 12 out of 627
# Page 2: 24 out of 627
# Page 3: 36 out of 627
# Page 4: 48 out of 627
# Page 5: 60 out of 627
# Page 6: 72 out of 627
# Page 7: 84 out of 627
# Page 8: 96 out of 627
# Page 9: 108 out of 627
# Page 10: 120 out of 627
# Page 11: 132 out of 627
# Page 12: 144 out of 627
# Page 13: 156 out of 627
# Page 14: 168 out of 627
# Page 15: 180 out of 627
# Page 16: 192 out of 627
# Page 17: 204 out of 627
# Page 18: 216 out of 627
# Page 19: 228 out of 627
# Page 20: 240 out of 627
# Page 21: 252 out of 627
# Page 22: 264 out of 627
# Page 23: 276 out of 627
# Page 24: 288 out of 627
# Page 25: 300 out of 627
# Page 26: 312 out of 627
# Page 27: 324 out of 627
# Page 28: 336 out of 627
# Page 29: 348 out of 627
# Page 30: 360 out of 627
# Page 31: 372 out of 627
# Page 32: 384 out of 627
# Page 33: 396 out of 627
# Page 34: 408 out of 627
# Page 35: 420 out of 627
# Page 36: 432 out of 627
# Page 37: 444 out of 627
# Page 38: 456 out of 627
# Page 39: 468 out of 627
# Page 40: 480 out of 627
# Page 41: 492 out of 627
# Page 42: 504 out of 627
# Page 43: 516 out of 627
# Page 44: 528 out of 627
# Page 45: 540 out of 627
# Page 46: 552 out of 627
# Page 47: 564 out of 627
# Page 48: 576 out of 627
# Page 49: 588 out of 627
# Page 50: 600 out of 627
# Page 51: 612 out of 627
# Page 52: 624 out of 627
# Page 53: 627 out of 627
# CPU times: total: 422 ms
# Wall time: 46 s

# %%
len(items)
# Out:
# 627

# %%
len(lookup)
# Out:
# 9

# %%
lookup.keys()
# Out:
# dict_keys(['Cuisine', 'Borough', 'Neighborhood', 'Accessibility', 'Meal Types', 'Weeks Participating', 'Has Menu', 'Founded By NYC Categories', 'Collections'])

# %%
lookup
# Out:
# {'Cuisine': {'Italian': {'count': 138,
#    'id': '3yTV00jjj7bszV7PNsxlyY',
#    'label': 'Italian',
#    'slug': 'italian'},
#   'Korean': {'count': 14,
#    'id': '6erFlIpnXYyPL4aBVDJPqe',
#    'label': 'Korean',
#    'slug': 'korean'},
#   'American (New)': {'count': 121,
#    'id': '2u5r3e6lPwri1BwWU31BbX',
#    'label': 'American (New)',
#    'slug': 'american-new'},
#   'Seafood': {'count': 48,
#    'id': '2nRMOe37rLv8HWZ5A3l4OI',
#    'label': 'Seafood',
#    'slug': 'seafood'},
#   'Chinese': {'count': 19,
#    'id': '6EOCCoIZAAC8JanUHdxBbY',
#    'label': 'Chinese',
#    'slug': 'chinese'},
#   'Asian Fusion': {'count': 24,
#    'id': '5HxPNXNUlgygLivi9gvQz',
#    'label': 'Asian Fusion',
#    'slug': 'asian-fusion'},
#   'Thai': {'count': 19,
#    'id': '1k9HRmtwlqvSdsJuYqb2m2',
#    'label': 'Thai',
#    'slug': 'thai'},
#   'Mexican': {'count': 27,
#    'id': '6lrkEqGroUEvKo551SI1oH',
#    'label': 'Mexican',
#    'slug': 'mexican'},
#   'Steakhouse': {'count': 57,
#    'id': '66gAlD86rRShshqk3iBr20',
#    'label': 'Steakhouse',
#    'slug': 'steakhouse'},
#   'American (Traditional)': {'count': 29,
#    'id': '5uaUeLgy2Su84FYBKP4LVg',
#    'label': 'American (Traditional)',
#    'slug': 'american-traditional'},
#   'Gastropub': {'count': 6,
#    'id': 'VH1UZBVqE1NKi99RSAsPb',
#    'label': 'Gastropub',
#    'slug': 'gastropub'},
#   'Indian': {'count': 13,
#    'id': '33Q5TQf50mmGwyj2UcpOt9',
#    'label': 'Indian',
#    'slug': 'indian'},
#   'French': {'count': 58,
#    'id': 'hqp75UjDB0fOqwSDraoSt',
#    'label': 'French',
#    'slug': 'french'},
#   'Japanese / Sushi': {'count': 46,
#    'id': '5mFtbP7WO79eKYANwxaLva',
#    'label': 'Japanese / Sushi',
#    'slug': 'japanese-sushi'},
#   'Spanish': {'count': 12,
#    'id': '5PlxK4HuEPhLkI6zH1BzM1',
#    'label': 'Spanish',
#    'slug': 'spanish'},
#   'Ukrainian': {'count': 1,
#    'id': '7D9A5BqDNdreHpMpbyXGGb',
#    'label': 'Ukrainian',
#    'slug': 'ukrainian'},
#   'Argentinian': {'count': 3,
#    'id': '4TF9Q2DNmlbrnw91EeM9Da',
#    'label': 'Argentinian',
#    'slug': 'argentinian'},
#   'Bars/Cocktails': {'count': 21,
#    'id': '76suAEbHFj4NstgNTJwdHl',
#    'label': 'Bars/Cocktails',
#    'slug': 'barscocktails'},
#   'Mediterranean': {'count': 45,
#    'id': '60iKLQ1Xjo4BGC2d67e2U7',
#    'label': 'Mediterranean',
#    'slug': 'mediterranean'},
#   'Greek': {'count': 22,
#    'id': '583zqMYoCTy26cFt6xdLI1',
#    'label': 'Greek',
#    'slug': 'greek'},
#   'Pizza': {'count': 12,
#    'id': '3mcQRMMO2B9Y784mU7OZdk',
#    'label': 'Pizza',
#    'slug': 'pizza'},
#   'Middle Eastern': {'count': 9,
#    'id': '4grdmRpwni8VDWTsmXNTe1',
#    'label': 'Middle Eastern',
#    'slug': 'middle-eastern'},
#   'Brazilian': {'count': 5,
#    'id': '1zolqpZ1JyJbqOeDNgFiNW',
#    'label': 'Brazilian',
#    'slug': 'brazilian'},
#   'Barbecue': {'count': 6,
#    'id': '6Xe9xXygaRtxKxF0JaNZFf',
#    'label': 'Barbecue',
#    'slug': 'barbecue'},
#   'Irish': {'count': 7,
#    'id': '3Q8A4wHvG1Gj9w0EUrMz5Q',
#    'label': 'Irish',
#    'slug': 'irish'},
#   'Latin American': {'count': 7,
#    'id': '2hebFB3NMBEI0HT37EqLlf',
#    'label': 'Latin American',
#    'slug': 'latin-american'},
#   'British': {'count': 3,
#    'id': '5OKA8ZkrMfaccjbksRfYDW',
#    'label': 'British',
#    'slug': 'british'},
#   'Burgers': {'count': 3,
#    'id': '4XEejlqHMZIid9cvI3370Q',
#    'label': 'Burgers',
#    'slug': 'burgers'},
#   'Turkish': {'count': 4,
#    'id': '65M2jfg10yM1D6h9Me3SMl',
#    'label': 'Turkish',
#    'slug': 'turkish'},
#   'Hawaiian': {'count': 1,
#    'id': 'taDjvz2zSpfYHzWVEqq0f',
#    'label': 'Hawaiian',
#    'slug': 'hawaiian'},
#   'Cuban': {'count': 4,
#    'id': '5SkyKh9qOj7Dd1ynwZ2G0T',
#    'label': 'Cuban',
#    'slug': 'cuban'},
#   'Vietnamese': {'count': 4,
#    'id': '7CYKNV83NIZmFkelYeQ7VK',
#    'label': 'Vietnamese',
#    'slug': 'vietnamese'},
#   'Eclectic': {'count': 11,
#    'id': '7cuqXb4GlRAkQVX7MM5PW3',
#    'label': 'Eclectic',
#    'slug': 'eclectic'},
#   'Vegan': {'count': 3,
#    'id': '7G9WpP5J6ac5cWt1MGhstm',
#    'label': 'Vegan',
#    'slug': 'vegan'},
#   'Puerto Rican': {'count': 2,
#    'id': '4o33kmYYkg1nzz0fPa05mV',
#    'label': 'Puerto Rican',
#    'slug': 'puerto-rican'},
#   'Eastern European': {'count': 3,
#    'id': '26eNuSmwdEJMr5UnVVeyae',
#    'label': 'Eastern European',
#    'slug': 'eastern-european'},
#   'Soul Food / Southern': {'count': 3,
#    'id': '2ZNSqOO1u1tVur0unoPFAB',
#    'label': 'Soul Food / Southern',
#    'slug': 'soul-food-southern'},
#   'Continental': {'count': 5,
#    'id': '6Z7jhDkkNpy93UFgyL43KU',
#    'label': 'Continental',
#    'slug': 'continental'},
#   'Modern European': {'count': 1,
#    'id': '1KDJqsoOBssNJFcXTcL4QE',
#    'label': 'Modern European',
#    'slug': 'modern-european'},
#   'Pan-Asian': {'count': 6,
#    'id': '4IHo2T1oNTEehrwBDHJE23',
#    'label': 'Pan-Asian',
#    'slug': 'pan-asian'},
#   'Caribbean': {'count': 6,
#    'id': '1BWHyz7T69If6Ilk5NRkwI',
#    'label': 'Caribbean',
#    'slug': 'caribbean'},
#   'Austrian': {'count': 2,
#    'id': 'OvkoMyGePU5FT0gQHYsO3',
#    'label': 'Austrian',
#    'slug': 'austrian'},
#   'Peruvian': {'count': 2,
#    'id': '56MdKhc9szecVGf2AkacOx',
#    'label': 'Peruvian',
#    'slug': 'peruvian'},
#   'Vegetarian': {'count': 3,
#    'id': '1bv92IV29i2YetCKbZExlk',
#    'label': 'Vegetarian',
#    'slug': 'vegetarian'},
#   'Belgian': {'count': 1,
#    'id': '7pdzkSXa4AUbT6N2jZEqqJ',
#    'label': 'Belgian',
#    'slug': 'belgian'},
#   'Southwestern': {'count': 1,
#    'id': '6p3TtvjmqaiCTtS0r5c5S1',
#    'label': 'Southwestern',
#    'slug': 'southwestern'},
#   'Cajun/Creole': {'count': 1,
#    'id': '5zUwQcYy94ZJs7r2eJF8m4',
#    'label': 'Cajun/Creole',
#    'slug': 'cajuncreole'},
#   'Taiwanese': {'count': 1,
#    'id': '2ZpO1etbB3DuNC1evhCSvO',
#    'label': 'Taiwanese',
#    'slug': 'taiwanese'},
#   'Delicatessen': {'count': 1,
#    'id': 'd7gV1F8AuNdSpGwIqfwwE',
#    'label': 'Delicatessen',
#    'slug': 'delicatessen'},
#   'New Zealand': {'count': 1,
#    'id': '11lhwWAzm5FNIsCEPBCn7S',
#    'label': 'New Zealand',
#    'slug': 'new-zealand'},
#   'Jamaican': {'count': 1,
#    'id': '5HvxVHowtfjvBUKidisRRJ',
#    'label': 'Jamaican',
#    'slug': 'jamaican'},
#   'African': {'count': 1,
#    'id': '6DbkztdPTACBKnINFOk8nW',
#    'label': 'African',
#    'slug': 'african'},
#   'Somali': {'count': 1,
#    'id': '7ktP9GpFxb8Fqnp9AWhwG4',
#    'label': 'Somali',
#    'slug': 'somali'},
#   'Malaysian': {'count': 2,
#    'id': '7BGDq9ZYy99R3SCMRCcv4T',
#    'label': 'Malaysian',
#    'slug': 'malaysian'},
#   'Colombian': {'count': 1,
#    'id': '7tBuZRpdL3H8Kimkf2qiq1',
#    'label': 'Colombian',
#    'slug': 'colombian'},
#   'label': 'Cuisine',
#   'type': 'multiselect',
#   'values': ['Italian',
#    'Korean',
#    'American (New)',
#    'Seafood',
#    'Chinese',
#    'Asian Fusion',
#    'Thai',
#    'Mexican',
#    'Steakhouse',
#    'American (Traditional)',
#    'Gastropub',
#    'Indian',
#    'French',
#    'Japanese / Sushi',
#    'Spanish',
#    'Ukrainian',
#    'Argentinian',
#    'Bars/Cocktails',
#    'Mediterranean',
#    'Greek',
#    'Pizza',
#    'Middle Eastern',
#    'Brazilian',
#    'Barbecue',
#    'Irish',
#    'Latin American',
#    'British',
#    'Burgers',
#    'Turkish',
#    'Hawaiian',
#    'Cuban',
#    'Vietnamese',
#    'Eclectic',
#    'Vegan',
#    'Puerto Rican',
#    'Eastern European',
#    'Soul Food / Southern',
#    'Continental',
#    'Modern European',
#    'Pan-Asian',
#    'Caribbean',
#    'Austrian',
#    'Peruvian',
#    'Vegetarian',
#    'Belgian',
#    'Southwestern',
#    'Cajun/Creole',
#    'Taiwanese',
#    'Delicatessen',
#    'New Zealand',
#    'Jamaican',
#    'African',
#    'Somali',
#    'Malaysian',
#    'Colombian'],
#   'lookupName': 'cuisines'},
#  'Borough': {'Manhattan': {'count': 518,
#    'id': '2NTEba3HJYoWwT28somHcc',
#    'label': 'Manhattan',
#    'slug': 'manhattan'},
#   'Brooklyn': {'count': 62,
#    'id': '3mTu46dYjcg3mB0MrgP5AU',
#    'label': 'Brooklyn',
#    'slug': 'brooklyn'},
#   'Queens': {'count': 35,
#    'id': 'ZLtdnTsUCk7o8gTSHfEgz',
#    'label': 'Queens',
#    'slug': 'queens'},
#   'The Bronx': {'count': 5,
#    'id': '3t5Bl1JjoJDRrbv83H7MRS',
#    'label': 'The Bronx',
#    'slug': 'the-bronx'},
#   'Staten Island': {'count': 7,
#    'id': '6bZ34HUjaMM5ZDPtc5UR7B',
#    'label': 'Staten Island',
#    'slug': 'staten-island'},
#   'label': 'Borough',
#   'type': 'multiselect',
#   'values': ['Manhattan', 'Brooklyn', 'Queens', 'The Bronx', 'Staten Island'],
#   'lookupName': 'borough'},
#  'Neighborhood': {'Midtown East': {'count': 99,
#    'id': '1yrv3RQN0fXSCHvHm82nHN',
#    'label': 'Midtown East',
#    'slug': 'midtown-east'},
#   'Lower East Side': {'count': 24,
#    'id': '2qN4P9hfEghwPq6sAjKVjA',
#    'label': 'Lower East Side',
#    'slug': 'lower-east-side'},
#   'Midtown West': {'count': 120,
#    'id': '61QB2f7blSGMaKZi1yfOLv',
#    'label': 'Midtown West',
#    'slug': 'midtown-west'},
#   'Flatiron District': {'count': 40,
#    'id': '7gYVRYq01uHCq2pYtNItT5',
#    'label': 'Flatiron District',
#    'slug': 'flatiron-district'},
#   'Hudson Square': {'count': 4,
#    'id': '5nCtsqHF2mhDULId9HCyxw',
#    'label': 'Hudson Square',
#    'slug': 'hudson-square'},
#   'Chelsea': {'count': 51,
#    'id': '34JJy3vOrcZxehSGau7gq9',
#    'label': 'Chelsea',
#    'slug': 'chelsea'},
#   'Garment District': {'count': 14,
#    'id': '23Ol3QxkVOJpbQeL8GPP2P',
#    'label': 'Garment District',
#    'slug': 'garment-district'},
#   'Upper East Side': {'count': 80,
#    'id': '2OrQvTjvaMRREDz0QGlIJU',
#    'label': 'Upper East Side',
#    'slug': 'upper-east-side'},
#   'Williamsburg': {'count': 44,
#    'id': 'jqTjGdFa7iLRDJ7Fy5BM0',
#    'label': 'Williamsburg',
#    'slug': 'williamsburg'},
#   'Midtown': {'count': 77,
#    'id': '1LExA8nslarYIovIHnDo2M',
#    'label': 'Midtown',
#    'slug': 'midtown'},
#   'Boerum Hill': {'count': 10,
#    'id': '1AH9V2IzLruG8F4diHBzRf',
#    'label': 'Boerum Hill',
#    'slug': 'boerum-hill'},
#   'East Village': {'count': 52,
#    'id': '6bUnDkwrgIUyGxGWohSJGi',
#    'label': 'East Village',
#    'slug': 'east-village'},
#   'West Village': {'count': 40,
#    'id': '1h1CKqntuJBlUEzuzszwKK',
#    'label': 'West Village',
#    'slug': 'west-village'},
#   'Upper West Side': {'count': 68,
#    'id': '2Fa3xmXblFpWnb67R744VL',
#    'label': 'Upper West Side',
#    'slug': 'upper-west-side'},
#   'Greenpoint': {'count': 4,
#    'id': '3Lqy1ED6Ht7eXqmSAkdpoy',
#    'label': 'Greenpoint',
#    'slug': 'greenpoint'},
#   'Herald Square': {'count': 14,
#    'id': '1Jj5rhV8eN7AYPmY4n2b5q',
#    'label': 'Herald Square',
#    'slug': 'herald-square'},
#   'Astoria': {'count': 12,
#    'id': '4DCR0vMxDtZFWcVOI0809b',
#    'label': 'Astoria',
#    'slug': 'astoria'},
#   'Tribeca': {'count': 16,
#    'id': 'E3FdzsWjyFbr6cyt75FS6',
#    'label': 'Tribeca',
#    'slug': 'tribeca'},
#   'Times Square/Theatre District': {'count': 79,
#    'id': '7bC6GrAOzXLvoJAGgTOdzl',
#    'label': 'Times Square/Theatre District',
#    'slug': 'times-squaretheatre-district'},
#   'Murray Hill': {'count': 24,
#    'id': 'XeL6xZNV0BHanR8jbsMuD',
#    'label': 'Murray Hill',
#    'slug': 'murray-hill'},
#   'Noho': {'count': 18,
#    'id': '6B1WbjxIFRHz6mNzkPW6v5',
#    'label': 'Noho',
#    'slug': 'noho'},
#   'Hells Kitchen': {'count': 41,
#    'id': '1LKdriQXICZbXvssQcQiWT',
#    'label': 'Hells Kitchen',
#    'slug': 'hells-kitchen'},
#   'Gramercy': {'count': 34,
#    'id': '6vN5GObLgLffMUPwv5UZu1',
#    'label': 'Gramercy',
#    'slug': 'gramercy'},
#   'Greenwich Village': {'count': 27,
#    'id': '4QangtuYUkuBbu7AU1SRSw',
#    'label': 'Greenwich Village',
#    'slug': 'greenwich-village'},
#   'Park Slope': {'count': 18,
#    'id': '26mZqmCzM8u5znaiAFS3zj',
#    'label': 'Park Slope',
#    'slug': 'park-slope'},
#   'Union Square': {'count': 22,
#    'id': '7BxqcAYVYoj33m3iwvkwqa',
#    'label': 'Union Square',
#    'slug': 'union-square'},
#   'Brooklyn Heights': {'count': 4,
#    'id': 'BrVmeYRTAoLVb6jwQz6SQ',
#    'label': 'Brooklyn Heights',
#    'slug': 'brooklyn-heights'},
#   'Meatpacking District': {'count': 8,
#    'id': '5fWzIA7KWA59Q5aCB5GnbC',
#    'label': 'Meatpacking District',
#    'slug': 'meatpacking-district'},
#   'Nomad': {'count': 38,
#    'id': '5dyV0RJlstwK2LoilQkyI1',
#    'label': 'Nomad',
#    'slug': 'nomad'},
#   'Harlem': {'count': 20,
#    'id': '4vY3o5tV1zIHNE8zuDH8ht',
#    'label': 'Harlem',
#    'slug': 'harlem'},
#   'Washington Heights': {'count': 4,
#    'id': '5mO0B8omv4Jg7RWBO9ivAQ',
#    'label': 'Washington Heights',
#    'slug': 'washington-heights'},
#   'Mott Haven': {'count': 4,
#    'id': '5bHTg9EW6XuXmpLYeL79FT',
#    'label': 'Mott Haven',
#    'slug': 'mott-haven'},
#   'Central Park': {'count': 4,
#    'id': '211skuRtHXTL5QiSLLEvgm',
#    'label': 'Central Park',
#    'slug': 'central-park'},
#   'Lower Manhattan': {'count': 36,
#    'id': '1ULligRcuT6hxnS5zFfWGl',
#    'label': 'Lower Manhattan',
#    'slug': 'lower-manhattan'},
#   'Bayside': {'count': 6,
#    'id': '41UtPfm5Xca1FVJWOEJe5w',
#    'label': 'Bayside',
#    'slug': 'bayside'},
#   'Hamilton Heights': {'count': 4,
#    'id': '3eqvm5n51tIaN4uBlQphPh',
#    'label': 'Hamilton Heights',
#    'slug': 'hamilton-heights'},
#   'Battery Park City': {'count': 10,
#    'id': '6KgmBWhznEz7Rcy2C5tYgL',
#    'label': 'Battery Park City',
#    'slug': 'battery-park-city'},
#   'Kips Bay': {'count': 5,
#    'id': '2jsST2ttADlnGkLYgpa8qI',
#    'label': 'Kips Bay',
#    'slug': 'kips-bay'},
#   'Soho': {'count': 28,
#    'id': '52LVi7xKOFZ0XnSF64Qu8W',
#    'label': 'Soho',
#    'slug': 'soho'},
#   'Forest Hills': {'count': 12,
#    'id': '4LtVjfuTm3Z4hb3YiAgAoC',
#    'label': 'Forest Hills',
#    'slug': 'forest-hills'},
#   'The Seaport': {'count': 16,
#    'id': '47OH6Jm8dnAvMDLyGaWzi8',
#    'label': 'The Seaport',
#    'slug': 'the-seaport'},
#   'Bloomfield': {'count': 2,
#    'id': 'FdQvQLO7SSdPV2fHI5X1u',
#    'label': 'Bloomfield',
#    'slug': 'bloomfield'},
#   'Long Island City': {'count': 12,
#    'id': '2n7urs7UPA2wOWpRm1uaf1',
#    'label': 'Long Island City',
#    'slug': 'long-island-city'},
#   'Hudson Yards': {'count': 14,
#    'id': '2KEl3016ktlIWbRHkhvCop',
#    'label': 'Hudson Yards',
#    'slug': 'hudson-yards'},
#   'Nolita': {'count': 14,
#    'id': '7FHG8RkEFefLGuEea4yHCO',
#    'label': 'Nolita',
#    'slug': 'nolita'},
#   'Rosebank': {'count': 2,
#    'id': '579qWajkpImw6Dkdk56p6o',
#    'label': 'Rosebank',
#    'slug': 'rosebank'},
#   'Prospect Heights': {'count': 8,
#    'id': '3GZrUyLQwjWgwYbLi9v98i',
#    'label': 'Prospect Heights',
#    'slug': 'prospect-heights'},
#   'St. George': {'count': 2,
#    'id': '1fVuJQBPkksFDDc37i0SIR',
#    'label': 'St. George',
#    'slug': 'st-george'},
#   'Bay Ridge': {'count': 8,
#    'id': '6HK93lYIFgNeFGIFzQQRCl',
#    'label': 'Bay Ridge',
#    'slug': 'bay-ridge'},
#   'Riverdale': {'count': 2,
#    'id': '2fgOX96OfhpO3WtNAdPl5r',
#    'label': 'Riverdale',
#    'slug': 'riverdale'},
#   'South Slope': {'count': 4,
#    'id': '5DiqiooihIrMNcJfTsr3ck',
#    'label': 'South Slope',
#    'slug': 'south-slope'},
#   'Jamaica': {'count': 2,
#    'id': '56LGR0FYDmfpR3HP5CjiJK',
#    'label': 'Jamaica',
#    'slug': 'jamaica'},
#   'New Hyde Park': {'count': 2,
#    'id': '5ZUFjiqujchswsCDEwlYnW',
#    'label': 'New Hyde Park',
#    'slug': 'new-hyde-park'},
#   'Woodhaven': {'count': 2,
#    'id': '1oRGiwPcrd2TK4xreBMMiU',
#    'label': 'Woodhaven',
#    'slug': 'woodhaven'},
#   'Little Italy': {'count': 4,
#    'id': '6WWAScC9CIjCCR6jgrExx3',
#    'label': 'Little Italy',
#    'slug': 'little-italy'},
#   'Belmont': {'count': 2,
#    'id': '4AUp3rWNx0xxVMLoKIq3kp',
#    'label': 'Belmont',
#    'slug': 'belmont'},
#   'Coney Island': {'count': 2,
#    'id': 'fgvIVvpt2SxAvJgAZm8Yw',
#    'label': 'Coney Island',
#    'slug': 'coney-island'},
#   'Flatlands': {'count': 2,
#    'id': '62qagzGg0M7YQrZzLdv5dl',
#    'label': 'Flatlands',
#    'slug': 'flatlands'},
#   'East Harlem': {'count': 4,
#    'id': 'lkb2nfAdErSztMlRJjE6n',
#    'label': 'East Harlem',
#    'slug': 'east-harlem'},
#   'Jackson Heights': {'count': 5,
#    'id': '749ggaz7Xy1RncGKQfhhEM',
#    'label': 'Jackson Heights',
#    'slug': 'jackson-heights'},
#   'Red Hook': {'count': 2,
#    'id': '15O7B8ROpOFDS9DyxU0buJ',
#    'label': 'Red Hook',
#    'slug': 'red-hook'},
#   'Flushing': {'count': 10,
#    'id': '1dPHBAhCeLrOjYuXWhgEFb',
#    'label': 'Flushing',
#    'slug': 'flushing'},
#   'Cobble Hill': {'count': 4,
#    'id': '1JKy9cQVz6BX5o7qSO5W1E',
#    'label': 'Cobble Hill',
#    'slug': 'cobble-hill'},
#   'Dumbo': {'count': 4,
#    'id': '5WfEIg9alXNmUJsl7CG3hs',
#    'label': 'Dumbo',
#    'slug': 'dumbo'},
#   'Alphabet City': {'count': 1,
#    'id': '7HCNMQRkqk9WeEdElXAVRF',
#    'label': 'Alphabet City',
#    'slug': 'alphabet-city'},
#   'Little Neck': {'count': 2,
#    'id': '1QSHOPOQ3AMbfqBqmrTghy',
#    'label': 'Little Neck',
#    'slug': 'little-neck'},
#   'New Dorp': {'count': 2,
#    'id': '2fCtkg8Q2iIkg6MiZJ3ppW',
#    'label': 'New Dorp',
#    'slug': 'new-dorp'},
#   'Koreatown': {'count': 6,
#    'id': '6ih6v4gaf3RRw2WqVEzww2',
#    'label': 'Koreatown',
#    'slug': 'koreatown'},
#   'Prospect Lefferts Gardens': {'count': 2,
#    'id': '4CmhGvHyl0RxsqLgEXrmFW',
#    'label': 'Prospect Lefferts Gardens',
#    'slug': 'prospect-lefferts-gardens'},
#   'Woodstock': {'count': 2,
#    'id': '27qMPhv3k7y867ktrjKhki',
#    'label': 'Woodstock',
#    'slug': 'woodstock'},
#   'Carroll Gardens': {'count': 4,
#    'id': '3OrsgsYkXbHfmVRJgehI35',
#    'label': 'Carroll Gardens',
#    'slug': 'carroll-gardens'},
#   'Tompkinsville': {'count': 2,
#    'id': '4qNRfz22WItCCh4t6UEA5p',
#    'label': 'Tompkinsville',
#    'slug': 'tompkinsville'},
#   'Port Morris': {'count': 1,
#    'id': '38mobknR3vRXgkN9iAvkS9',
#    'label': 'Port Morris',
#    'slug': 'port-morris'},
#   'Elmhurst': {'count': 2,
#    'id': '2Ly0gcQhSDKTvu0Aup93Gg',
#    'label': 'Elmhurst',
#    'slug': 'elmhurst'},
#   'West Brighton': {'count': 2,
#    'id': '3Q1FonXdHYtLtrkwNnBLE2',
#    'label': 'West Brighton',
#    'slug': 'west-brighton'},
#   'Howard Beach': {'count': 2,
#    'id': '6NaiYluUtHoJBGK6CDNfLR',
#    'label': 'Howard Beach',
#    'slug': 'howard-beach'},
#   'East Elmhurst': {'count': 2,
#    'id': '7LI6820itCXFFCZv3iurPu',
#    'label': 'East Elmhurst',
#    'slug': 'east-elmhurst'},
#   'Todt Hill': {'count': 2,
#    'id': '7Ylxe39vQEzjLJOGB6K9m',
#    'label': 'Todt Hill',
#    'slug': 'todt-hill'},
#   'Morningside Heights': {'count': 2,
#    'id': '2ovKDGD5Sy8SpkSyYcp7CH',
#    'label': 'Morningside Heights',
#    'slug': 'morningside-heights'},
#   'Downtown Brooklyn': {'count': 4,
#    'id': '1OIRg3CypIeCorXfFJ5DNP',
#    'label': 'Downtown Brooklyn',
#    'slug': 'downtown-brooklyn'},
#   'label': 'Neighborhood',
#   'type': 'multiselect',
#   'values': ['Midtown East',
#    'Lower East Side',
#    'Midtown West',
#    'Flatiron District',
#    'Hudson Square',
#    'Chelsea',
#    'Garment District',
#    'Upper East Side',
#    'Williamsburg',
#    'Midtown',
#    'Boerum Hill',
#    'East Village',
#    'West Village',
#    'Upper West Side',
#    'Greenpoint',
#    'Herald Square',
#    'Astoria',
#    'Tribeca',
#    'Times Square/Theatre District',
#    'Murray Hill',
#    'Noho',
#    'Hells Kitchen',
#    'Gramercy',
#    'Greenwich Village',
#    'Park Slope',
#    'Union Square',
#    'Brooklyn Heights',
#    'Meatpacking District',
#    'Nomad',
#    'Harlem',
#    'Washington Heights',
#    'Mott Haven',
#    'Central Park',
#    'Lower Manhattan',
#    'Bayside',
#    'Hamilton Heights',
#    'Battery Park City',
#    'Kips Bay',
#    'Soho',
#    'Forest Hills',
#    'The Seaport',
#    'Bloomfield',
#    'Long Island City',
#    'Hudson Yards',
#    'Nolita',
#    'Rosebank',
#    'Prospect Heights',
#    'St. George',
#    'Bay Ridge',
#    'Riverdale',
#    'South Slope',
#    'Jamaica',
#    'New Hyde Park',
#    'Woodhaven',
#    'Little Italy',
#    'Belmont',
#    'Coney Island',
#    'Flatlands',
#    'East Harlem',
#    'Jackson Heights',
#    'Red Hook',
#    'Flushing',
#    'Cobble Hill',
#    'Dumbo',
#    'Alphabet City',
#    'Little Neck',
#    'New Dorp',
#    'Koreatown',
#    'Prospect Lefferts Gardens',
#    'Woodstock',
#    'Carroll Gardens',
#    'Tompkinsville',
#    'Port Morris',
#    'Elmhurst',
#    'West Brighton',
#    'Howard Beach',
#    'East Elmhurst',
#    'Todt Hill',
#    'Morningside Heights',
#    'Downtown Brooklyn'],
#   'lookupName': 'neighborhood'},
#  'Accessibility': {'Wheelchair Accessible': {'count': 576,
#    'id': '3UnxXQdjBymIv5gWofDT00',
#    'label': 'Wheelchair Accessible',
#    'slug': 'wheelchair-accessible'},
#   'Large Print': {'count': 185,
#    'id': '7F66X8cEpvhXvFRLuqQuep',
#    'label': 'Large Print',
#    'slug': 'large-print'},
#   'Braille': {'count': 39,
#    'id': '1w4zeGXXQ31MWeV2zYKqoQ',
#    'label': 'Braille',
#    'slug': 'braille'},
#   'Open and/or Closed Captioned': {'count': 1,
#    'id': '2EWQakO37Rm88FjjOh1CQ1',
#    'label': 'Open and/or Closed Captioned',
#    'slug': 'open-andor-closed-captioned'},
#   'Volume Control Telephone': {'count': 1,
#    'id': 'ZUO4Ezfzu7LSowc8kPWeq',
#    'label': 'Volume Control Telephone',
#    'slug': 'volume-control-telephone'},
#   'Assistive Listening System': {'count': 1,
#    'id': '3k1gFy7gmkd6G1T6McTea4',
#    'label': 'Assistive Listening System',
#    'slug': 'assistive-listening-system'},
#   'label': 'Accessibility',
#   'type': 'multiselect',
#   'values': ['Wheelchair Accessible',
#    'Large Print',
#    'Braille',
#    'Open and/or Closed Captioned',
#    'Volume Control Telephone',
#    'Assistive Listening System'],
#   'lookupName': 'accessibility'},
#  'Meal Types': {'$45 Lunch Price': {'count': 115},
#   '$60 Dinner Price': {'count': 308},
#   '$45 Dinner Price': {'count': 255},
#   '$30 Lunch Price': {'count': 254},
#   '$60 Sunday Dinner Price': {'count': 228},
#   '$45 Sunday Dinner Price': {'count': 198},
#   '$30 Sunday Lunch/Brunch Price': {'count': 127},
#   '$45 Sunday Lunch/Brunch Price': {'count': 82},
#   '$60 Lunch Price': {'count': 22},
#   '$30 Dinner Price': {'count': 22},
#   '$30 Sunday Dinner Price': {'count': 22},
#   '$60 Sunday Lunch/Brunch Price': {'count': 15},
#   'label': 'Meal Types',
#   'type': 'multiselect',
#   'values': ['$45 Lunch Price',
#    '$60 Dinner Price',
#    '$45 Dinner Price',
#    '$30 Lunch Price',
#    '$60 Sunday Dinner Price',
#    '$45 Sunday Dinner Price',
#    '$30 Sunday Lunch/Brunch Price',
#    '$45 Sunday Lunch/Brunch Price',
#    '$60 Lunch Price',
#    '$30 Dinner Price',
#    '$30 Sunday Dinner Price',
#    '$60 Sunday Lunch/Brunch Price'],
#   'lookupName': 'mealTypes'},
#  'Weeks Participating': {'Week 3 (Aug 4 - Aug 10)': {'count': 611},
#   'Week 4 (Aug 11 - Aug 17)': {'count': 605},
#   'Week 5 (Aug 18 - Aug 24)': {'count': 450},
#   'Week 6 (Aug 25 - Aug 31)': {'count': 432},
#   'Week 2 (July 28 - Aug 3)': {'count': 625},
#   'label': 'Weeks Participating',
#   'type': 'multiselect',
#   'values': ['Week 3 (Aug 4 - Aug 10)',
#    'Week 4 (Aug 11 - Aug 17)',
#    'Week 5 (Aug 18 - Aug 24)',
#    'Week 6 (Aug 25 - Aug 31)',
#    'Week 2 (July 28 - Aug 3)'],
#   'lookupName': 'inclusionWeeks'},
#  'Has Menu': {'true': {'count': 448},
#   'false': {'count': 179},
#   'label': 'Has Menu',
#   'type': 'toggle',
#   'values': ['true', 'false'],
#   'lookupName': 'hasMenu'},
#  'Founded By NYC Categories': {'Restaurant Signature Dish': {'count': 92,
#    'id': '6V5rSjb80DVddiSy6im5DR',
#    'label': 'Restaurant Signature Dish',
#    'slug': 'rw-fbnyc-restaurant-signature-dish'},
#   'NYC Original Dish': {'count': 52,
#    'id': '4rdEWIgrDKFsGqJWZ45v9B',
#    'label': 'NYC Original Dish',
#    'slug': 'rw-fbnyc-nyc-original-dish'},
#   '$16.25 Cocktail': {'count': 81,
#    'id': '6qWcFJDodv5spn11ZBjRS0',
#    'label': '$16.25 Cocktail',
#    'slug': 'rw-fbnyc-1625-cocktail'},
#   'NYC Original Cocktail': {'count': 31,
#    'id': '6xqiypVjUTJWhWijgbKeTu',
#    'label': 'NYC Original Cocktail',
#    'slug': 'rw-fbnyc-nyc-original-cocktail'},
#   'Restaurant Signature Cocktail': {'count': 50,
#    'id': '3c29wDd7x4x6ArYj8gVfdR',
#    'label': 'Restaurant Signature Cocktail',
#    'slug': 'rw-fbnyc-restaurant-signature-cocktail'},
#   '$16.25 Dish': {'count': 23,
#    'id': '2GebBqrL06NBXwiQmQ5fsv',
#    'label': '$16.25 Dish',
#    'slug': 'rw-fbnyc-1625-dish'},
#   'label': 'Founded By NYC Categories',
#   'type': 'multiselect',
#   'values': ['Restaurant Signature Dish',
#    'NYC Original Dish',
#    '$16.25 Cocktail',
#    'NYC Original Cocktail',
#    'Restaurant Signature Cocktail',
#    '$16.25 Dish'],
#   'lookupName': 'rwFbnycCategories'},
#  'Collections': {'celebrity-chefs': {'count': 8},
#   'around-the-boroughs': {'count': 13},
#   'dress-for-the-occasion': {'count': 13},
#   'summer-vibes': {'count': 9},
#   'for-the-foodies': {'count': 9},
#   'date-night': {'count': 12},
#   'hidden-gems': {'count': 10},
#   'classic-restaurants': {'count': 9},
#   'label': 'Collections',
#   'type': 'multiselect',
#   'values': ['celebrity-chefs',
#    'around-the-boroughs',
#    'dress-for-the-occasion',
#    'summer-vibes',
#    'for-the-foodies',
#    'date-night',
#    'hidden-gems',
#    'classic-restaurants'],
#   'lookupName': 'collections'}}

# %%
restaurant_data_df = pd.DataFrame(items)
restaurant_data_df["rest_week_site_url"] = "https://www.nyctourism.com/restaurant-week/"+restaurant_data_df["slug"]
restaurant_data_df["image_url"] = restaurant_data_df["image"].map(lambda x: f'https:{x["url"]}' if x["url"] else None)
restaurant_data_df
# Out:
#        borough       neighborhood primaryCategory    primaryLocation  \
# 0    Manhattan       Midtown East     Restaurants       Midtown East
# 1    Manhattan    Lower East Side     Restaurants    Lower East Side
# 2    Manhattan       Midtown West     Restaurants       Midtown West
# 3    Manhattan  Flatiron District     Restaurants  Flatiron District
# 4    Manhattan      Hudson Square       Nightlife      Hudson Square
# ..         ...                ...             ...                ...
# 622  Manhattan    Upper East Side     Restaurants    Upper East Side
# 623  Manhattan    Upper West Side     Restaurants    Upper West Side
# 624   Brooklyn  Downtown Brooklyn     Restaurants  Downtown Brooklyn
# 625  Manhattan      Herald Square     Restaurants      Herald Square
# 626  Manhattan       Midtown West     Restaurants       Midtown West
#
#                                             ctaButtons  \
# 0    {'primary': {'label': {'presale': False, 'gene...
# 1    {'primary': {'label': {'presale': False, 'gene...
# 2    {'primary': {'label': {'presale': False, 'gene...
# 3    {'primary': {'label': {'presale': False, 'gene...
# 4    {'primary': {'label': {'presale': False, 'gene...
# ..                                                 ...
# 622  {'primary': {'label': {'presale': False, 'gene...
# 623  {'primary': {'label': {'presale': False, 'gene...
# 624  {'primary': {'label': {'presale': False, 'gene...
# 625  {'primary': {'label': {'presale': False, 'gene...
# 626  {'primary': {'label': {'presale': False, 'gene...
#
#                                 tags  \
# 0            [Italian, Midtown East]
# 1          [Korean, Lower East Side]
# 2     [American (New), Midtown West]
# 3       [Italian, Flatiron District]
# 4    [American (New), Hudson Square]
# ..                               ...
# 622    [Steakhouse, Upper East Side]
# 623        [French, Upper West Side]
# 624   [Brazilian, Downtown Brooklyn]
# 625      [Steakhouse, Herald Square]
# 626          [Seafood, Midtown West]
#
#                                        shortTitle  \
# 0                                Fresco by Scotto
# 1                                         Sae Ron
# 2                                    Redeye Grill
# 3                       Zero Otto Nove - Flatiron
# 4                   Torch & Crown Brewing Company
# ..                                            ...
# 622                                 Catch n' Chop
# 623                      Amélie - Upper West Side
# 624  Fogo de Chão Brazilian Steakhouse - Brooklyn
# 625                                Atlantis Prime
# 626                                 Docks Off 5th
#
#                                            slug  \
# 0                              fresco-by-scotto
# 1                                       sae-ron
# 2                                  redeye-grill
# 3                                zero-otto-nove
# 4                   torch-crown-brewing-company
# ..                                          ...
# 622                                catch-n-chop
# 623                      amelie-upper-west-side
# 624  fogo-de-chao-brazilian-steakhouse-brooklyn
# 625                              atlantis-prime
# 626                               docks-off-5th
#
#                                                  image  \
# 0    {'url': '//images.ctfassets.net/1aemqu6a6t65/J...
# 1    {'url': '//images.ctfassets.net/1aemqu6a6t65/1...
# 2    {'url': '//images.ctfassets.net/1aemqu6a6t65/7...
# 3    {'url': '//images.ctfassets.net/1aemqu6a6t65/5...
# 4    {'url': '//images.ctfassets.net/1aemqu6a6t65/3...
# ..                                                 ...
# 622                             {'url': '', 'alt': ''}
# 623                             {'url': '', 'alt': ''}
# 624                             {'url': '', 'alt': ''}
# 625                             {'url': '', 'alt': ''}
# 626                             {'url': '', 'alt': ''}
#
#                                                summary  \
# 0    For more than three decades, Fresco by Scotto,...
# 1    Sae Ron is a modern Korean kitchen dedicated t...
# 2    This cavernous restaurant captures the richnes...
# 3    Roberto Paciullo's Flatiron District restauran...
# 4    Torch & Crown Brewing Company, in Hudson Squar...
# ..                                                 ...
# 622  Catch n' Chop, situated on the Upper East Side...
# 623  "La Petite Amélie" is smaller and more intimat...
# 624  This Downtown Brooklyn restaurant features an ...
# 625  Atlantis Prime offers a refined surf-and-turf ...
# 626  This seafood-centric restaurant, steps away fr...
#
#                                       website menuFileUrl        collections  \
# 0            https://www.frescobyscottony.com              [celebrity-chefs]
# 1                   https://www.saeronnyc.com                             []
# 2                 https://www.redeyegrill.com                             []
# 3                https://zeroottonove.com/nyc                             []
# 4               https://www.torchandcrown.com                             []
# ..                                        ...         ...                ...
# 622                    https://catchnchop.com                             []
# 623           https://www.amelieupperwest.com                             []
# 624  https://fogodechao.com/location/brooklyn                             []
# 625   https://www.atlantisprimerestaurant.com                             []
# 626                   https://docksoff5th.com                             []
#
#                                              mealTypes  \
# 0                  [$45 Lunch Price, $60 Dinner Price]
# 1                                   [$45 Dinner Price]
# 2    [$30 Lunch Price, $60 Dinner Price, $60 Sunday...
# 3    [$45 Lunch Price, $45 Dinner Price, $45 Sunday...
# 4    [$30 Lunch Price, $45 Dinner Price, $30 Sunday...
# ..                                                 ...
# 622  [$60 Dinner Price, $30 Sunday Lunch/Brunch Pri...
# 623        [$45 Dinner Price, $45 Sunday Dinner Price]
# 624        [$60 Dinner Price, $60 Sunday Dinner Price]
# 625  [$30 Lunch Price, $60 Dinner Price, $30 Sunday...
# 626  [$45 Lunch Price, $60 Dinner Price, $45 Sunday...
#
#                                restaurantInclusionWeek  \
# 0    [Week 3 (Aug 4 - Aug 10), Week 4 (Aug 11 - Aug...
# 1    [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 2    [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 3    [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 4    [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# ..                                                 ...
# 622  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 623  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 624  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 625  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 626  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
#
#                                              ecommerce  \
# 0                                                  NaN
# 1                                                  NaN
# 2    {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 3    {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 4                                                  NaN
# ..                                                 ...
# 622  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 623                                                NaN
# 624  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 625                                                NaN
# 626  {'title': 'OpenTable', 'partnerName': 'OpenTab...
#
#                                     rest_week_site_url  \
# 0    https://www.nyctourism.com/restaurant-week/fre...
# 1    https://www.nyctourism.com/restaurant-week/sae...
# 2    https://www.nyctourism.com/restaurant-week/red...
# 3    https://www.nyctourism.com/restaurant-week/zer...
# 4    https://www.nyctourism.com/restaurant-week/tor...
# ..                                                 ...
# 622  https://www.nyctourism.com/restaurant-week/cat...
# 623  https://www.nyctourism.com/restaurant-week/ame...
# 624  https://www.nyctourism.com/restaurant-week/fog...
# 625  https://www.nyctourism.com/restaurant-week/atl...
# 626  https://www.nyctourism.com/restaurant-week/doc...
#
#                                              image_url
# 0    https://images.ctfassets.net/1aemqu6a6t65/JRA3...
# 1    https://images.ctfassets.net/1aemqu6a6t65/1G7R...
# 2    https://images.ctfassets.net/1aemqu6a6t65/79jn...
# 3    https://images.ctfassets.net/1aemqu6a6t65/54rW...
# 4    https://images.ctfassets.net/1aemqu6a6t65/3WPZ...
# ..                                                 ...
# 622                                               None
# 623                                               None
# 624                                               None
# 625                                               None
# 626                                               None
#
# [627 rows x 18 columns]

# %%
restaurant_data_df.to_excel("rw_restaurants_2025-07_v4.xlsx", index=False)

# %%
import json
with open('lookup.json', 'w') as f:
    json.dump(lookup, f)
