# %%
import pandas as pd
import requests

# %%
BASE_URL = "https://program-api.nyctourism.com/restaurant-week"
HEADERS = {"x-api-key": "lTQSe929f34fohKaNq0OH53mdVL0yncvtqmuUG6i"}

# %%
def make_request(page=1, lookup={}):
    payload = {
        "page": page,
        "lookup": lookup
    }
    response = requests.post(BASE_URL, headers=HEADERS, json=payload)
    return response.json()

# %%
# %%time
count = 0
page = 1
items = []

while True:
    print(f"Page {page}:", end="")
    res_json = make_request(page)
    items += res_json["items"]
    count += len(res_json["items"])
    page += 1
    print(f" {count} out of {res_json["count"]}")
    if count >= res_json["count"]:
        break
        
lookup = res_json["lookup"]
# Out:
# Page 1: 12 out of 611
# Page 2: 24 out of 611
# Page 3: 36 out of 611
# Page 4: 48 out of 611
# Page 5: 60 out of 611
# Page 6: 72 out of 611
# Page 7: 84 out of 611
# Page 8: 96 out of 611
# Page 9: 108 out of 611
# Page 10: 120 out of 611
# Page 11: 132 out of 611
# Page 12: 144 out of 611
# Page 13: 156 out of 611
# Page 14: 168 out of 611
# Page 15: 180 out of 611
# Page 16: 192 out of 611
# Page 17: 204 out of 611
# Page 18: 216 out of 611
# Page 19: 228 out of 611
# Page 20: 240 out of 611
# Page 21: 252 out of 611
# Page 22: 264 out of 611
# Page 23: 276 out of 611
# Page 24: 288 out of 611
# Page 25: 300 out of 611
# Page 26: 312 out of 611
# Page 27: 324 out of 611
# Page 28: 336 out of 611
# Page 29: 348 out of 611
# Page 30: 360 out of 611
# Page 31: 372 out of 611
# Page 32: 384 out of 611
# Page 33: 396 out of 611
# Page 34: 408 out of 611
# Page 35: 420 out of 611
# Page 36: 432 out of 611
# Page 37: 444 out of 611
# Page 38: 456 out of 611
# Page 39: 468 out of 611
# Page 40: 480 out of 611
# Page 41: 492 out of 611
# Page 42: 504 out of 611
# Page 43: 516 out of 611
# Page 44: 528 out of 611
# Page 45: 540 out of 611
# Page 46: 552 out of 611
# Page 47: 564 out of 611
# Page 48: 576 out of 611
# Page 49: 588 out of 611
# Page 50: 600 out of 611
# Page 51: 611 out of 611
# CPU times: total: 469 ms
# Wall time: 3min 1s

# %%
len(items)
# Out:
# 611

# %%
len(lookup)
# Out:
# 9

# %%
lookup.keys()
# Out:
# dict_keys(['Cuisine', 'Borough', 'Neighborhood', 'Accessibility', 'Meal Types', 'Weeks Participating', 'Has Menu', 'Founded By NYC Categories', 'Collections'])

# %%
lookup
# Out:
# {'Cuisine': {'Italian': {'count': 137,
#    'id': '3yTV00jjj7bszV7PNsxlyY',
#    'label': 'Italian',
#    'slug': 'italian'},
#   'Austrian': {'count': 2,
#    'id': 'OvkoMyGePU5FT0gQHYsO3',
#    'label': 'Austrian',
#    'slug': 'austrian'},
#   'Eclectic': {'count': 11,
#    'id': '7cuqXb4GlRAkQVX7MM5PW3',
#    'label': 'Eclectic',
#    'slug': 'eclectic'},
#   'Japanese / Sushi': {'count': 44,
#    'id': '5mFtbP7WO79eKYANwxaLva',
#    'label': 'Japanese / Sushi',
#    'slug': 'japanese-sushi'},
#   'American (New)': {'count': 121,
#    'id': '2u5r3e6lPwri1BwWU31BbX',
#    'label': 'American (New)',
#    'slug': 'american-new'},
#   'Mexican': {'count': 27,
#    'id': '6lrkEqGroUEvKo551SI1oH',
#    'label': 'Mexican',
#    'slug': 'mexican'},
#   'Thai': {'count': 19,
#    'id': '1k9HRmtwlqvSdsJuYqb2m2',
#    'label': 'Thai',
#    'slug': 'thai'},
#   'Seafood': {'count': 43,
#    'id': '2nRMOe37rLv8HWZ5A3l4OI',
#    'label': 'Seafood',
#    'slug': 'seafood'},
#   'French': {'count': 58,
#    'id': 'hqp75UjDB0fOqwSDraoSt',
#    'label': 'French',
#    'slug': 'french'},
#   'Steakhouse': {'count': 56,
#    'id': '66gAlD86rRShshqk3iBr20',
#    'label': 'Steakhouse',
#    'slug': 'steakhouse'},
#   'Asian Fusion': {'count': 24,
#    'id': '5HxPNXNUlgygLivi9gvQz',
#    'label': 'Asian Fusion',
#    'slug': 'asian-fusion'},
#   'Greek': {'count': 21,
#    'id': '583zqMYoCTy26cFt6xdLI1',
#    'label': 'Greek',
#    'slug': 'greek'},
#   'Mediterranean': {'count': 44,
#    'id': '60iKLQ1Xjo4BGC2d67e2U7',
#    'label': 'Mediterranean',
#    'slug': 'mediterranean'},
#   'Turkish': {'count': 3,
#    'id': '65M2jfg10yM1D6h9Me3SMl',
#    'label': 'Turkish',
#    'slug': 'turkish'},
#   'Korean': {'count': 14,
#    'id': '6erFlIpnXYyPL4aBVDJPqe',
#    'label': 'Korean',
#    'slug': 'korean'},
#   'Gastropub': {'count': 6,
#    'id': 'VH1UZBVqE1NKi99RSAsPb',
#    'label': 'Gastropub',
#    'slug': 'gastropub'},
#   'American (Traditional)': {'count': 28,
#    'id': '5uaUeLgy2Su84FYBKP4LVg',
#    'label': 'American (Traditional)',
#    'slug': 'american-traditional'},
#   'Continental': {'count': 5,
#    'id': '6Z7jhDkkNpy93UFgyL43KU',
#    'label': 'Continental',
#    'slug': 'continental'},
#   'Bars/Cocktails': {'count': 21,
#    'id': '76suAEbHFj4NstgNTJwdHl',
#    'label': 'Bars/Cocktails',
#    'slug': 'barscocktails'},
#   'Hawaiian': {'count': 1,
#    'id': 'taDjvz2zSpfYHzWVEqq0f',
#    'label': 'Hawaiian',
#    'slug': 'hawaiian'},
#   'Argentinian': {'count': 3,
#    'id': '4TF9Q2DNmlbrnw91EeM9Da',
#    'label': 'Argentinian',
#    'slug': 'argentinian'},
#   'Latin American': {'count': 7,
#    'id': '2hebFB3NMBEI0HT37EqLlf',
#    'label': 'Latin American',
#    'slug': 'latin-american'},
#   'Chinese': {'count': 18,
#    'id': '6EOCCoIZAAC8JanUHdxBbY',
#    'label': 'Chinese',
#    'slug': 'chinese'},
#   'Vegan': {'count': 3,
#    'id': '7G9WpP5J6ac5cWt1MGhstm',
#    'label': 'Vegan',
#    'slug': 'vegan'},
#   'Vegetarian': {'count': 3,
#    'id': '1bv92IV29i2YetCKbZExlk',
#    'label': 'Vegetarian',
#    'slug': 'vegetarian'},
#   'New Zealand': {'count': 1,
#    'id': '11lhwWAzm5FNIsCEPBCn7S',
#    'label': 'New Zealand',
#    'slug': 'new-zealand'},
#   'Burgers': {'count': 3,
#    'id': '4XEejlqHMZIid9cvI3370Q',
#    'label': 'Burgers',
#    'slug': 'burgers'},
#   'Vietnamese': {'count': 4,
#    'id': '7CYKNV83NIZmFkelYeQ7VK',
#    'label': 'Vietnamese',
#    'slug': 'vietnamese'},
#   'Middle Eastern': {'count': 7,
#    'id': '4grdmRpwni8VDWTsmXNTe1',
#    'label': 'Middle Eastern',
#    'slug': 'middle-eastern'},
#   'British': {'count': 3,
#    'id': '5OKA8ZkrMfaccjbksRfYDW',
#    'label': 'British',
#    'slug': 'british'},
#   'Spanish': {'count': 12,
#    'id': '5PlxK4HuEPhLkI6zH1BzM1',
#    'label': 'Spanish',
#    'slug': 'spanish'},
#   'Cuban': {'count': 4,
#    'id': '5SkyKh9qOj7Dd1ynwZ2G0T',
#    'label': 'Cuban',
#    'slug': 'cuban'},
#   'Pizza': {'count': 11,
#    'id': '3mcQRMMO2B9Y784mU7OZdk',
#    'label': 'Pizza',
#    'slug': 'pizza'},
#   'Indian': {'count': 13,
#    'id': '33Q5TQf50mmGwyj2UcpOt9',
#    'label': 'Indian',
#    'slug': 'indian'},
#   'Peruvian': {'count': 2,
#    'id': '56MdKhc9szecVGf2AkacOx',
#    'label': 'Peruvian',
#    'slug': 'peruvian'},
#   'Barbecue': {'count': 5,
#    'id': '6Xe9xXygaRtxKxF0JaNZFf',
#    'label': 'Barbecue',
#    'slug': 'barbecue'},
#   'Brazilian': {'count': 4,
#    'id': '1zolqpZ1JyJbqOeDNgFiNW',
#    'label': 'Brazilian',
#    'slug': 'brazilian'},
#   'Eastern European': {'count': 3,
#    'id': '26eNuSmwdEJMr5UnVVeyae',
#    'label': 'Eastern European',
#    'slug': 'eastern-european'},
#   'Ukrainian': {'count': 1,
#    'id': '7D9A5BqDNdreHpMpbyXGGb',
#    'label': 'Ukrainian',
#    'slug': 'ukrainian'},
#   'Irish': {'count': 7,
#    'id': '3Q8A4wHvG1Gj9w0EUrMz5Q',
#    'label': 'Irish',
#    'slug': 'irish'},
#   'Puerto Rican': {'count': 2,
#    'id': '4o33kmYYkg1nzz0fPa05mV',
#    'label': 'Puerto Rican',
#    'slug': 'puerto-rican'},
#   'Pan-Asian': {'count': 6,
#    'id': '4IHo2T1oNTEehrwBDHJE23',
#    'label': 'Pan-Asian',
#    'slug': 'pan-asian'},
#   'Soul Food / Southern': {'count': 3,
#    'id': '2ZNSqOO1u1tVur0unoPFAB',
#    'label': 'Soul Food / Southern',
#    'slug': 'soul-food-southern'},
#   'Belgian': {'count': 1,
#    'id': '7pdzkSXa4AUbT6N2jZEqqJ',
#    'label': 'Belgian',
#    'slug': 'belgian'},
#   'Southwestern': {'count': 1,
#    'id': '6p3TtvjmqaiCTtS0r5c5S1',
#    'label': 'Southwestern',
#    'slug': 'southwestern'},
#   'Delicatessen': {'count': 1,
#    'id': 'd7gV1F8AuNdSpGwIqfwwE',
#    'label': 'Delicatessen',
#    'slug': 'delicatessen'},
#   'Modern European': {'count': 1,
#    'id': '1KDJqsoOBssNJFcXTcL4QE',
#    'label': 'Modern European',
#    'slug': 'modern-european'},
#   'Cajun/Creole': {'count': 1,
#    'id': '5zUwQcYy94ZJs7r2eJF8m4',
#    'label': 'Cajun/Creole',
#    'slug': 'cajuncreole'},
#   'Caribbean': {'count': 6,
#    'id': '1BWHyz7T69If6Ilk5NRkwI',
#    'label': 'Caribbean',
#    'slug': 'caribbean'},
#   'Taiwanese': {'count': 1,
#    'id': '2ZpO1etbB3DuNC1evhCSvO',
#    'label': 'Taiwanese',
#    'slug': 'taiwanese'},
#   'Jamaican': {'count': 1,
#    'id': '5HvxVHowtfjvBUKidisRRJ',
#    'label': 'Jamaican',
#    'slug': 'jamaican'},
#   'Malaysian': {'count': 2,
#    'id': '7BGDq9ZYy99R3SCMRCcv4T',
#    'label': 'Malaysian',
#    'slug': 'malaysian'},
#   'Colombian': {'count': 1,
#    'id': '7tBuZRpdL3H8Kimkf2qiq1',
#    'label': 'Colombian',
#    'slug': 'colombian'},
#   'African': {'count': 1,
#    'id': '6DbkztdPTACBKnINFOk8nW',
#    'label': 'African',
#    'slug': 'african'},
#   'Somali': {'count': 1,
#    'id': '7ktP9GpFxb8Fqnp9AWhwG4',
#    'label': 'Somali',
#    'slug': 'somali'},
#   'label': 'Cuisine',
#   'type': 'multiselect',
#   'values': ['Italian',
#    'Austrian',
#    'Eclectic',
#    'Japanese / Sushi',
#    'American (New)',
#    'Mexican',
#    'Thai',
#    'Seafood',
#    'French',
#    'Steakhouse',
#    'Asian Fusion',
#    'Greek',
#    'Mediterranean',
#    'Turkish',
#    'Korean',
#    'Gastropub',
#    'American (Traditional)',
#    'Continental',
#    'Bars/Cocktails',
#    'Hawaiian',
#    'Argentinian',
#    'Latin American',
#    'Chinese',
#    'Vegan',
#    'Vegetarian',
#    'New Zealand',
#    'Burgers',
#    'Vietnamese',
#    'Middle Eastern',
#    'British',
#    'Spanish',
#    'Cuban',
#    'Pizza',
#    'Indian',
#    'Peruvian',
#    'Barbecue',
#    'Brazilian',
#    'Eastern European',
#    'Ukrainian',
#    'Irish',
#    'Puerto Rican',
#    'Pan-Asian',
#    'Soul Food / Southern',
#    'Belgian',
#    'Southwestern',
#    'Delicatessen',
#    'Modern European',
#    'Cajun/Creole',
#    'Caribbean',
#    'Taiwanese',
#    'Jamaican',
#    'Malaysian',
#    'Colombian',
#    'African',
#    'Somali'],
#   'lookupName': 'cuisines'},
#  'Borough': {'Manhattan': {'count': 508,
#    'id': '2NTEba3HJYoWwT28somHcc',
#    'label': 'Manhattan',
#    'slug': 'manhattan'},
#   'Brooklyn': {'count': 61,
#    'id': '3mTu46dYjcg3mB0MrgP5AU',
#    'label': 'Brooklyn',
#    'slug': 'brooklyn'},
#   'Queens': {'count': 31,
#    'id': 'ZLtdnTsUCk7o8gTSHfEgz',
#    'label': 'Queens',
#    'slug': 'queens'},
#   'The Bronx': {'count': 4,
#    'id': '3t5Bl1JjoJDRrbv83H7MRS',
#    'label': 'The Bronx',
#    'slug': 'the-bronx'},
#   'Staten Island': {'count': 7,
#    'id': '6bZ34HUjaMM5ZDPtc5UR7B',
#    'label': 'Staten Island',
#    'slug': 'staten-island'},
#   'label': 'Borough',
#   'type': 'multiselect',
#   'values': ['Manhattan', 'Brooklyn', 'Queens', 'The Bronx', 'Staten Island'],
#   'lookupName': 'borough'},
#  'Neighborhood': {'Midtown East': {'count': 97,
#    'id': '1yrv3RQN0fXSCHvHm82nHN',
#    'label': 'Midtown East',
#    'slug': 'midtown-east'},
#   'Midtown': {'count': 73,
#    'id': '1LExA8nslarYIovIHnDo2M',
#    'label': 'Midtown',
#    'slug': 'midtown'},
#   'West Village': {'count': 40,
#    'id': '1h1CKqntuJBlUEzuzszwKK',
#    'label': 'West Village',
#    'slug': 'west-village'},
#   'Park Slope': {'count': 18,
#    'id': '26mZqmCzM8u5znaiAFS3zj',
#    'label': 'Park Slope',
#    'slug': 'park-slope'},
#   'Flatiron District': {'count': 40,
#    'id': '7gYVRYq01uHCq2pYtNItT5',
#    'label': 'Flatiron District',
#    'slug': 'flatiron-district'},
#   'Lower East Side': {'count': 24,
#    'id': '2qN4P9hfEghwPq6sAjKVjA',
#    'label': 'Lower East Side',
#    'slug': 'lower-east-side'},
#   'Williamsburg': {'count': 42,
#    'id': 'jqTjGdFa7iLRDJ7Fy5BM0',
#    'label': 'Williamsburg',
#    'slug': 'williamsburg'},
#   'Chelsea': {'count': 49,
#    'id': '34JJy3vOrcZxehSGau7gq9',
#    'label': 'Chelsea',
#    'slug': 'chelsea'},
#   'Noho': {'count': 18,
#    'id': '6B1WbjxIFRHz6mNzkPW6v5',
#    'label': 'Noho',
#    'slug': 'noho'},
#   'Times Square/Theatre District': {'count': 77,
#    'id': '7bC6GrAOzXLvoJAGgTOdzl',
#    'label': 'Times Square/Theatre District',
#    'slug': 'times-squaretheatre-district'},
#   'Kips Bay': {'count': 5,
#    'id': '2jsST2ttADlnGkLYgpa8qI',
#    'label': 'Kips Bay',
#    'slug': 'kips-bay'},
#   'Soho': {'count': 26,
#    'id': '52LVi7xKOFZ0XnSF64Qu8W',
#    'label': 'Soho',
#    'slug': 'soho'},
#   'Long Island City': {'count': 10,
#    'id': '2n7urs7UPA2wOWpRm1uaf1',
#    'label': 'Long Island City',
#    'slug': 'long-island-city'},
#   'Midtown West': {'count': 117,
#    'id': '61QB2f7blSGMaKZi1yfOLv',
#    'label': 'Midtown West',
#    'slug': 'midtown-west'},
#   'Lower Manhattan': {'count': 36,
#    'id': '1ULligRcuT6hxnS5zFfWGl',
#    'label': 'Lower Manhattan',
#    'slug': 'lower-manhattan'},
#   'Astoria': {'count': 12,
#    'id': '4DCR0vMxDtZFWcVOI0809b',
#    'label': 'Astoria',
#    'slug': 'astoria'},
#   'Harlem': {'count': 20,
#    'id': '4vY3o5tV1zIHNE8zuDH8ht',
#    'label': 'Harlem',
#    'slug': 'harlem'},
#   'Upper East Side': {'count': 78,
#    'id': '2OrQvTjvaMRREDz0QGlIJU',
#    'label': 'Upper East Side',
#    'slug': 'upper-east-side'},
#   'Upper West Side': {'count': 66,
#    'id': '2Fa3xmXblFpWnb67R744VL',
#    'label': 'Upper West Side',
#    'slug': 'upper-west-side'},
#   'Hudson Square': {'count': 4,
#    'id': '5nCtsqHF2mhDULId9HCyxw',
#    'label': 'Hudson Square',
#    'slug': 'hudson-square'},
#   'Koreatown': {'count': 6,
#    'id': '6ih6v4gaf3RRw2WqVEzww2',
#    'label': 'Koreatown',
#    'slug': 'koreatown'},
#   'Gramercy': {'count': 34,
#    'id': '6vN5GObLgLffMUPwv5UZu1',
#    'label': 'Gramercy',
#    'slug': 'gramercy'},
#   'Herald Square': {'count': 14,
#    'id': '1Jj5rhV8eN7AYPmY4n2b5q',
#    'label': 'Herald Square',
#    'slug': 'herald-square'},
#   'East Village': {'count': 50,
#    'id': '6bUnDkwrgIUyGxGWohSJGi',
#    'label': 'East Village',
#    'slug': 'east-village'},
#   'Tribeca': {'count': 16,
#    'id': 'E3FdzsWjyFbr6cyt75FS6',
#    'label': 'Tribeca',
#    'slug': 'tribeca'},
#   'Greenwich Village': {'count': 27,
#    'id': '4QangtuYUkuBbu7AU1SRSw',
#    'label': 'Greenwich Village',
#    'slug': 'greenwich-village'},
#   'Meatpacking District': {'count': 8,
#    'id': '5fWzIA7KWA59Q5aCB5GnbC',
#    'label': 'Meatpacking District',
#    'slug': 'meatpacking-district'},
#   'Hells Kitchen': {'count': 41,
#    'id': '1LKdriQXICZbXvssQcQiWT',
#    'label': 'Hells Kitchen',
#    'slug': 'hells-kitchen'},
#   'Boerum Hill': {'count': 10,
#    'id': '1AH9V2IzLruG8F4diHBzRf',
#    'label': 'Boerum Hill',
#    'slug': 'boerum-hill'},
#   'Nolita': {'count': 14,
#    'id': '7FHG8RkEFefLGuEea4yHCO',
#    'label': 'Nolita',
#    'slug': 'nolita'},
#   'Garment District': {'count': 14,
#    'id': '23Ol3QxkVOJpbQeL8GPP2P',
#    'label': 'Garment District',
#    'slug': 'garment-district'},
#   'Forest Hills': {'count': 10,
#    'id': '4LtVjfuTm3Z4hb3YiAgAoC',
#    'label': 'Forest Hills',
#    'slug': 'forest-hills'},
#   'Bayside': {'count': 6,
#    'id': '41UtPfm5Xca1FVJWOEJe5w',
#    'label': 'Bayside',
#    'slug': 'bayside'},
#   'Nomad': {'count': 36,
#    'id': '5dyV0RJlstwK2LoilQkyI1',
#    'label': 'Nomad',
#    'slug': 'nomad'},
#   'The Seaport': {'count': 16,
#    'id': '47OH6Jm8dnAvMDLyGaWzi8',
#    'label': 'The Seaport',
#    'slug': 'the-seaport'},
#   'Bay Ridge': {'count': 8,
#    'id': '6HK93lYIFgNeFGIFzQQRCl',
#    'label': 'Bay Ridge',
#    'slug': 'bay-ridge'},
#   'Dumbo': {'count': 4,
#    'id': '5WfEIg9alXNmUJsl7CG3hs',
#    'label': 'Dumbo',
#    'slug': 'dumbo'},
#   'Greenpoint': {'count': 4,
#    'id': '3Lqy1ED6Ht7eXqmSAkdpoy',
#    'label': 'Greenpoint',
#    'slug': 'greenpoint'},
#   'Hudson Yards': {'count': 14,
#    'id': '2KEl3016ktlIWbRHkhvCop',
#    'label': 'Hudson Yards',
#    'slug': 'hudson-yards'},
#   'Woodhaven': {'count': 2,
#    'id': '1oRGiwPcrd2TK4xreBMMiU',
#    'label': 'Woodhaven',
#    'slug': 'woodhaven'},
#   'East Harlem': {'count': 4,
#    'id': 'lkb2nfAdErSztMlRJjE6n',
#    'label': 'East Harlem',
#    'slug': 'east-harlem'},
#   'Battery Park City': {'count': 10,
#    'id': '6KgmBWhznEz7Rcy2C5tYgL',
#    'label': 'Battery Park City',
#    'slug': 'battery-park-city'},
#   'Cobble Hill': {'count': 4,
#    'id': '1JKy9cQVz6BX5o7qSO5W1E',
#    'label': 'Cobble Hill',
#    'slug': 'cobble-hill'},
#   'Union Square': {'count': 20,
#    'id': '7BxqcAYVYoj33m3iwvkwqa',
#    'label': 'Union Square',
#    'slug': 'union-square'},
#   'Hamilton Heights': {'count': 4,
#    'id': '3eqvm5n51tIaN4uBlQphPh',
#    'label': 'Hamilton Heights',
#    'slug': 'hamilton-heights'},
#   'Central Park': {'count': 4,
#    'id': '211skuRtHXTL5QiSLLEvgm',
#    'label': 'Central Park',
#    'slug': 'central-park'},
#   'Jamaica': {'count': 2,
#    'id': '56LGR0FYDmfpR3HP5CjiJK',
#    'label': 'Jamaica',
#    'slug': 'jamaica'},
#   'Prospect Heights': {'count': 8,
#    'id': '3GZrUyLQwjWgwYbLi9v98i',
#    'label': 'Prospect Heights',
#    'slug': 'prospect-heights'},
#   'Murray Hill': {'count': 24,
#    'id': 'XeL6xZNV0BHanR8jbsMuD',
#    'label': 'Murray Hill',
#    'slug': 'murray-hill'},
#   'Brooklyn Heights': {'count': 4,
#    'id': 'BrVmeYRTAoLVb6jwQz6SQ',
#    'label': 'Brooklyn Heights',
#    'slug': 'brooklyn-heights'},
#   'Flushing': {'count': 8,
#    'id': '1dPHBAhCeLrOjYuXWhgEFb',
#    'label': 'Flushing',
#    'slug': 'flushing'},
#   'Red Hook': {'count': 2,
#    'id': '15O7B8ROpOFDS9DyxU0buJ',
#    'label': 'Red Hook',
#    'slug': 'red-hook'},
#   'Riverdale': {'count': 2,
#    'id': '2fgOX96OfhpO3WtNAdPl5r',
#    'label': 'Riverdale',
#    'slug': 'riverdale'},
#   'Little Italy': {'count': 4,
#    'id': '6WWAScC9CIjCCR6jgrExx3',
#    'label': 'Little Italy',
#    'slug': 'little-italy'},
#   'New Hyde Park': {'count': 2,
#    'id': '5ZUFjiqujchswsCDEwlYnW',
#    'label': 'New Hyde Park',
#    'slug': 'new-hyde-park'},
#   'Alphabet City': {'count': 1,
#    'id': '7HCNMQRkqk9WeEdElXAVRF',
#    'label': 'Alphabet City',
#    'slug': 'alphabet-city'},
#   'Belmont': {'count': 2,
#    'id': '4AUp3rWNx0xxVMLoKIq3kp',
#    'label': 'Belmont',
#    'slug': 'belmont'},
#   'Rosebank': {'count': 2,
#    'id': '579qWajkpImw6Dkdk56p6o',
#    'label': 'Rosebank',
#    'slug': 'rosebank'},
#   'New Dorp': {'count': 2,
#    'id': '2fCtkg8Q2iIkg6MiZJ3ppW',
#    'label': 'New Dorp',
#    'slug': 'new-dorp'},
#   'Mott Haven': {'count': 2,
#    'id': '5bHTg9EW6XuXmpLYeL79FT',
#    'label': 'Mott Haven',
#    'slug': 'mott-haven'},
#   'Prospect Lefferts Gardens': {'count': 2,
#    'id': '4CmhGvHyl0RxsqLgEXrmFW',
#    'label': 'Prospect Lefferts Gardens',
#    'slug': 'prospect-lefferts-gardens'},
#   'Washington Heights': {'count': 4,
#    'id': '5mO0B8omv4Jg7RWBO9ivAQ',
#    'label': 'Washington Heights',
#    'slug': 'washington-heights'},
#   'Little Neck': {'count': 2,
#    'id': '1QSHOPOQ3AMbfqBqmrTghy',
#    'label': 'Little Neck',
#    'slug': 'little-neck'},
#   'South Slope': {'count': 4,
#    'id': '5DiqiooihIrMNcJfTsr3ck',
#    'label': 'South Slope',
#    'slug': 'south-slope'},
#   'Woodstock': {'count': 2,
#    'id': '27qMPhv3k7y867ktrjKhki',
#    'label': 'Woodstock',
#    'slug': 'woodstock'},
#   'Jackson Heights': {'count': 5,
#    'id': '749ggaz7Xy1RncGKQfhhEM',
#    'label': 'Jackson Heights',
#    'slug': 'jackson-heights'},
#   'Flatlands': {'count': 2,
#    'id': '62qagzGg0M7YQrZzLdv5dl',
#    'label': 'Flatlands',
#    'slug': 'flatlands'},
#   'St. George': {'count': 2,
#    'id': '1fVuJQBPkksFDDc37i0SIR',
#    'label': 'St. George',
#    'slug': 'st-george'},
#   'Bloomfield': {'count': 2,
#    'id': 'FdQvQLO7SSdPV2fHI5X1u',
#    'label': 'Bloomfield',
#    'slug': 'bloomfield'},
#   'Coney Island': {'count': 2,
#    'id': 'fgvIVvpt2SxAvJgAZm8Yw',
#    'label': 'Coney Island',
#    'slug': 'coney-island'},
#   'Carroll Gardens': {'count': 4,
#    'id': '3OrsgsYkXbHfmVRJgehI35',
#    'label': 'Carroll Gardens',
#    'slug': 'carroll-gardens'},
#   'Clinton Hill': {'count': 2,
#    'id': '6S1Wdv1BhLyWGjqPUK1d6l',
#    'label': 'Clinton Hill',
#    'slug': 'clinton-hill'},
#   'Morningside Heights': {'count': 2,
#    'id': '2ovKDGD5Sy8SpkSyYcp7CH',
#    'label': 'Morningside Heights',
#    'slug': 'morningside-heights'},
#   'East Elmhurst': {'count': 2,
#    'id': '7LI6820itCXFFCZv3iurPu',
#    'label': 'East Elmhurst',
#    'slug': 'east-elmhurst'},
#   'West Brighton': {'count': 2,
#    'id': '3Q1FonXdHYtLtrkwNnBLE2',
#    'label': 'West Brighton',
#    'slug': 'west-brighton'},
#   'Tompkinsville': {'count': 2,
#    'id': '4qNRfz22WItCCh4t6UEA5p',
#    'label': 'Tompkinsville',
#    'slug': 'tompkinsville'},
#   'Downtown Brooklyn': {'count': 2,
#    'id': '1OIRg3CypIeCorXfFJ5DNP',
#    'label': 'Downtown Brooklyn',
#    'slug': 'downtown-brooklyn'},
#   'Elmhurst': {'count': 2,
#    'id': '2Ly0gcQhSDKTvu0Aup93Gg',
#    'label': 'Elmhurst',
#    'slug': 'elmhurst'},
#   'Todt Hill': {'count': 2,
#    'id': '7Ylxe39vQEzjLJOGB6K9m',
#    'label': 'Todt Hill',
#    'slug': 'todt-hill'},
#   'label': 'Neighborhood',
#   'type': 'multiselect',
#   'values': ['Midtown East',
#    'Midtown',
#    'West Village',
#    'Park Slope',
#    'Flatiron District',
#    'Lower East Side',
#    'Williamsburg',
#    'Chelsea',
#    'Noho',
#    'Times Square/Theatre District',
#    'Kips Bay',
#    'Soho',
#    'Long Island City',
#    'Midtown West',
#    'Lower Manhattan',
#    'Astoria',
#    'Harlem',
#    'Upper East Side',
#    'Upper West Side',
#    'Hudson Square',
#    'Koreatown',
#    'Gramercy',
#    'Herald Square',
#    'East Village',
#    'Tribeca',
#    'Greenwich Village',
#    'Meatpacking District',
#    'Hells Kitchen',
#    'Boerum Hill',
#    'Nolita',
#    'Garment District',
#    'Forest Hills',
#    'Bayside',
#    'Nomad',
#    'The Seaport',
#    'Bay Ridge',
#    'Dumbo',
#    'Greenpoint',
#    'Hudson Yards',
#    'Woodhaven',
#    'East Harlem',
#    'Battery Park City',
#    'Cobble Hill',
#    'Union Square',
#    'Hamilton Heights',
#    'Central Park',
#    'Jamaica',
#    'Prospect Heights',
#    'Murray Hill',
#    'Brooklyn Heights',
#    'Flushing',
#    'Red Hook',
#    'Riverdale',
#    'Little Italy',
#    'New Hyde Park',
#    'Alphabet City',
#    'Belmont',
#    'Rosebank',
#    'New Dorp',
#    'Mott Haven',
#    'Prospect Lefferts Gardens',
#    'Washington Heights',
#    'Little Neck',
#    'South Slope',
#    'Woodstock',
#    'Jackson Heights',
#    'Flatlands',
#    'St. George',
#    'Bloomfield',
#    'Coney Island',
#    'Carroll Gardens',
#    'Clinton Hill',
#    'Morningside Heights',
#    'East Elmhurst',
#    'West Brighton',
#    'Tompkinsville',
#    'Downtown Brooklyn',
#    'Elmhurst',
#    'Todt Hill'],
#   'lookupName': 'neighborhood'},
#  'Accessibility': {'Wheelchair Accessible': {'count': 561,
#    'id': '3UnxXQdjBymIv5gWofDT00',
#    'label': 'Wheelchair Accessible',
#    'slug': 'wheelchair-accessible'},
#   'Large Print': {'count': 177,
#    'id': '7F66X8cEpvhXvFRLuqQuep',
#    'label': 'Large Print',
#    'slug': 'large-print'},
#   'Assistive Listening System': {'count': 1,
#    'id': '3k1gFy7gmkd6G1T6McTea4',
#    'label': 'Assistive Listening System',
#    'slug': 'assistive-listening-system'},
#   'Braille': {'count': 38,
#    'id': '1w4zeGXXQ31MWeV2zYKqoQ',
#    'label': 'Braille',
#    'slug': 'braille'},
#   'Open and/or Closed Captioned': {'count': 1,
#    'id': '2EWQakO37Rm88FjjOh1CQ1',
#    'label': 'Open and/or Closed Captioned',
#    'slug': 'open-andor-closed-captioned'},
#   'Volume Control Telephone': {'count': 1,
#    'id': 'ZUO4Ezfzu7LSowc8kPWeq',
#    'label': 'Volume Control Telephone',
#    'slug': 'volume-control-telephone'},
#   'label': 'Accessibility',
#   'type': 'multiselect',
#   'values': ['Wheelchair Accessible',
#    'Large Print',
#    'Assistive Listening System',
#    'Braille',
#    'Open and/or Closed Captioned',
#    'Volume Control Telephone'],
#   'lookupName': 'accessibility'},
#  'Meal Types': {'$60 Dinner Price': {'count': 302},
#   '$45 Lunch Price': {'count': 111},
#   '$45 Sunday Lunch/Brunch Price': {'count': 79},
#   '$60 Sunday Dinner Price': {'count': 219},
#   '$30 Lunch Price': {'count': 248},
#   '$45 Dinner Price': {'count': 248},
#   '$30 Sunday Lunch/Brunch Price': {'count': 125},
#   '$45 Sunday Dinner Price': {'count': 195},
#   '$60 Lunch Price': {'count': 23},
#   '$30 Dinner Price': {'count': 23},
#   '$30 Sunday Dinner Price': {'count': 22},
#   '$60 Sunday Lunch/Brunch Price': {'count': 13},
#   'label': 'Meal Types',
#   'type': 'multiselect',
#   'values': ['$60 Dinner Price',
#    '$45 Lunch Price',
#    '$45 Sunday Lunch/Brunch Price',
#    '$60 Sunday Dinner Price',
#    '$30 Lunch Price',
#    '$45 Dinner Price',
#    '$30 Sunday Lunch/Brunch Price',
#    '$45 Sunday Dinner Price',
#    '$60 Lunch Price',
#    '$30 Dinner Price',
#    '$30 Sunday Dinner Price',
#    '$60 Sunday Lunch/Brunch Price'],
#   'lookupName': 'mealTypes'},
#  'Weeks Participating': {'Week 1 (July 21 - July 27)': {'count': 604},
#   'Week 2 (July 28 - Aug 3)': {'count': 608},
#   'Week 3 (Aug 4 - Aug 10)': {'count': 594},
#   'Week 4 (Aug 11 - Aug 17)': {'count': 585},
#   'Week 5 (Aug 18 - Aug 24)': {'count': 436},
#   'Week 6 (Aug 25 - Aug 31)': {'count': 421},
#   'label': 'Weeks Participating',
#   'type': 'multiselect',
#   'values': ['Week 1 (July 21 - July 27)',
#    'Week 2 (July 28 - Aug 3)',
#    'Week 3 (Aug 4 - Aug 10)',
#    'Week 4 (Aug 11 - Aug 17)',
#    'Week 5 (Aug 18 - Aug 24)',
#    'Week 6 (Aug 25 - Aug 31)'],
#   'lookupName': 'inclusionWeeks'},
#  'Has Menu': {'true': {'count': 419},
#   'false': {'count': 192},
#   'label': 'Has Menu',
#   'type': 'toggle',
#   'values': ['true', 'false'],
#   'lookupName': 'hasMenu'},
#  'Founded By NYC Categories': {'Restaurant Signature Dish': {'count': 90,
#    'id': '6V5rSjb80DVddiSy6im5DR',
#    'label': 'Restaurant Signature Dish',
#    'slug': 'rw-fbnyc-restaurant-signature-dish'},
#   'Restaurant Signature Cocktail': {'count': 48,
#    'id': '3c29wDd7x4x6ArYj8gVfdR',
#    'label': 'Restaurant Signature Cocktail',
#    'slug': 'rw-fbnyc-restaurant-signature-cocktail'},
#   '$16.25 Cocktail': {'count': 81,
#    'id': '6qWcFJDodv5spn11ZBjRS0',
#    'label': '$16.25 Cocktail',
#    'slug': 'rw-fbnyc-1625-cocktail'},
#   'NYC Original Cocktail': {'count': 31,
#    'id': '6xqiypVjUTJWhWijgbKeTu',
#    'label': 'NYC Original Cocktail',
#    'slug': 'rw-fbnyc-nyc-original-cocktail'},
#   'NYC Original Dish': {'count': 52,
#    'id': '4rdEWIgrDKFsGqJWZ45v9B',
#    'label': 'NYC Original Dish',
#    'slug': 'rw-fbnyc-nyc-original-dish'},
#   '$16.25 Dish': {'count': 23,
#    'id': '2GebBqrL06NBXwiQmQ5fsv',
#    'label': '$16.25 Dish',
#    'slug': 'rw-fbnyc-1625-dish'},
#   'label': 'Founded By NYC Categories',
#   'type': 'multiselect',
#   'values': ['Restaurant Signature Dish',
#    'Restaurant Signature Cocktail',
#    '$16.25 Cocktail',
#    'NYC Original Cocktail',
#    'NYC Original Dish',
#    '$16.25 Dish'],
#   'lookupName': 'rwFbnycCategories'},
#  'Collections': {'date-night': {'count': 12},
#   'classic-restaurants': {'count': 9},
#   'for-the-foodies': {'count': 9},
#   'around-the-boroughs': {'count': 13},
#   'hidden-gems': {'count': 10},
#   'celebrity-chefs': {'count': 8},
#   'dress-for-the-occasion': {'count': 13},
#   'summer-vibes': {'count': 9},
#   'label': 'Collections',
#   'type': 'multiselect',
#   'values': ['date-night',
#    'classic-restaurants',
#    'for-the-foodies',
#    'around-the-boroughs',
#    'hidden-gems',
#    'celebrity-chefs',
#    'dress-for-the-occasion',
#    'summer-vibes'],
#   'lookupName': 'collections'}}

# %%
restaurant_data_df = pd.DataFrame(items)
restaurant_data_df["rest_week_site_url"] = "https://www.nyctourism.com/restaurant-week/"+restaurant_data_df["slug"]
restaurant_data_df["image_url"] = restaurant_data_df["image"].map(lambda x: f'https:{x["url"]}' if x["url"] else None)
restaurant_data_df
# Out:
#            borough       neighborhood primaryCategory    primaryLocation  \
# 0        Manhattan       Midtown East     Restaurants       Midtown East
# 1        Manhattan       West Village     Restaurants       West Village
# 2         Brooklyn         Park Slope     Restaurants         Park Slope
# 3        Manhattan  Flatiron District     Restaurants  Flatiron District
# 4        Manhattan    Lower East Side     Restaurants    Lower East Side
# ..             ...                ...             ...                ...
# 606  Staten Island          Todt Hill     Restaurants          Todt Hill
# 607       Brooklyn       Williamsburg     Restaurants       Williamsburg
# 608       Brooklyn       Williamsburg       Nightlife       Williamsburg
# 609      Manhattan            Chelsea     Restaurants            Chelsea
# 610      Manhattan       West Village     Restaurants       West Village
#
#                                             ctaButtons  \
# 0    {'primary': {'label': {'presale': False, 'gene...
# 1    {'primary': {'label': {'presale': False, 'gene...
# 2    {'primary': {'label': {'presale': False, 'gene...
# 3    {'primary': {'label': {'presale': False, 'gene...
# 4    {'primary': {'label': {'presale': False, 'gene...
# ..                                                 ...
# 606  {'primary': {'label': {'presale': False, 'gene...
# 607  {'primary': {'label': {'presale': False, 'gene...
# 608  {'primary': {'label': {'presale': False, 'gene...
# 609  {'primary': {'label': {'presale': False, 'gene...
# 610  {'primary': {'label': {'presale': False, 'gene...
#
#                                       tags                shortTitle  \
# 0                  [Italian, Midtown East]                Casa Lever
# 1                 [Austrian, West Village]                    Wallsé
# 2           [Japanese / Sushi, Park Slope]               Muteki Udon
# 3    [Japanese / Sushi, Flatiron District]             Aqua New York
# 4        [American (New), Lower East Side]                     Essex
# ..                                     ...                       ...
# 606               [Continental, Todt Hill]                Max's Esca
# 607         [American (New), Williamsburg]                   Sungold
# 608                [Italian, Williamsburg]               Little Fino
# 609            [Japanese / Sushi, Chelsea]               Asuka Sushi
# 610         [American (New), West Village]  Jack & Charlie’s No. 118
#
#                          slug  \
# 0                  casa-lever
# 1                      wallse
# 2                 muteki-udon
# 3               aqua-new-york
# 4                       essex
# ..                        ...
# 606                 maxs-esca
# 607                   sungold
# 608               little-fino
# 609               asuka-sushi
# 610  jack-and-charlies-no-118
#
#                                                  image  \
# 0    {'url': '//images.ctfassets.net/1aemqu6a6t65/5...
# 1    {'url': '//images.ctfassets.net/1aemqu6a6t65/4...
# 2    {'url': '//images.ctfassets.net/1aemqu6a6t65/C...
# 3    {'url': '//images.ctfassets.net/1aemqu6a6t65/4...
# 4    {'url': '//images.ctfassets.net/1aemqu6a6t65/4...
# ..                                                 ...
# 606                             {'url': '', 'alt': ''}
# 607                             {'url': '', 'alt': ''}
# 608                             {'url': '', 'alt': ''}
# 609                             {'url': '', 'alt': ''}
# 610                             {'url': '', 'alt': ''}
#
#                                                summary  \
# 0    At Casa Lever, Modern art and timeless archite...
# 1    This modern European restaurant offers an impe...
# 2    Visit this Park Slope restaurant for an unforg...
# 3    Aqua New York has two separate restaurants—Aqu...
# 4    Located in the historic Essex Street Market Bu...
# ..                                                 ...
# 606  Max's Esca is a premier destination for except...
# 607  With an eye on the Mediterranean, chef Michael...
# 608  Little Fino is an all day neighborhood bar and...
# 609  From various rolls to teriyaki, and many mouth...
# 610  At Jack & Charlie’s No. 118, nostalgia meets m...
#
#                                 website menuFileUrl collections  \
# 0             https://www.casalever.com                      []
# 1                https://www.wallse.com                      []
# 2                https://mutekiudon.com                      []
# 3                  https://aqua-nyc.com                      []
# 4              https://www.essexnyc.com                      []
# ..                                  ...         ...         ...
# 606            https://www.maxsesca.com                      []
# 607           https://www.sungoldbk.com                      []
# 608       https://www.littlefinonyc.com                      []
# 609        https://www.asukasushiny.com                      []
# 610  https://www.jackandcharlies118.com                      []
#
#                                              mealTypes  \
# 0                                   [$60 Dinner Price]
# 1                                   [$60 Dinner Price]
# 2    [$45 Lunch Price, $60 Dinner Price, $45 Sunday...
# 3    [$30 Lunch Price, $60 Dinner Price, $60 Sunday...
# 4    [$45 Dinner Price, $30 Sunday Lunch/Brunch Pri...
# ..                                                 ...
# 606                                 [$60 Dinner Price]
# 607  [$30 Lunch Price, $45 Dinner Price, $30 Sunday...
# 608                                  [$30 Lunch Price]
# 609  [$30 Lunch Price, $60 Dinner Price, $30 Sunday...
# 610        [$60 Dinner Price, $60 Sunday Dinner Price]
#
#                                restaurantInclusionWeek  \
# 0    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 1    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 2    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 3    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 4    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# ..                                                 ...
# 606  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 607  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 608  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 609  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 610  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
#
#                                              ecommerce  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4    {'title': 'OpenTable', 'partnerName': 'OpenTab...
# ..                                                 ...
# 606                                                NaN
# 607  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 608  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 609  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 610                                                NaN
#
#                                     rest_week_site_url  \
# 0    https://www.nyctourism.com/restaurant-week/cas...
# 1    https://www.nyctourism.com/restaurant-week/wallse
# 2    https://www.nyctourism.com/restaurant-week/mut...
# 3    https://www.nyctourism.com/restaurant-week/aqu...
# 4     https://www.nyctourism.com/restaurant-week/essex
# ..                                                 ...
# 606  https://www.nyctourism.com/restaurant-week/max...
# 607  https://www.nyctourism.com/restaurant-week/sun...
# 608  https://www.nyctourism.com/restaurant-week/lit...
# 609  https://www.nyctourism.com/restaurant-week/asu...
# 610  https://www.nyctourism.com/restaurant-week/jac...
#
#                                              image_url
# 0    https://images.ctfassets.net/1aemqu6a6t65/5bH2...
# 1    https://images.ctfassets.net/1aemqu6a6t65/4dNX...
# 2    https://images.ctfassets.net/1aemqu6a6t65/CCK7...
# 3    https://images.ctfassets.net/1aemqu6a6t65/4uSd...
# 4    https://images.ctfassets.net/1aemqu6a6t65/4oIY...
# ..                                                 ...
# 606                                               None
# 607                                               None
# 608                                               None
# 609                                               None
# 610                                               None
#
# [611 rows x 18 columns]

# %%
restaurant_data_df.to_excel("rw_resturants_2025-07.xlsx", index=False)
