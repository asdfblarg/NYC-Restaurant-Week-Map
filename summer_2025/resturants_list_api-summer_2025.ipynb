# %%
import pandas as pd
import requests

# %%
BASE_URL = "https://program-api.nyctourism.com/restaurant-week"
HEADERS = {"x-api-key": "lTQSe929f34fohKaNq0OH53mdVL0yncvtqmuUG6i"}

# %%
def make_request(page=1, lookup={}):
    payload = {
        "page": page,
        "lookup": lookup
    }
    response = requests.post(BASE_URL, headers=HEADERS, json=payload)
    return response.json()

# %%
# %%time
count = 0
page = 1
items = []

while True:
    print(f"Page {page}:", end="")
    res_json = make_request(page)
    items += res_json["items"]
    count += len(res_json["items"])
    page += 1
    print(f" {count} out of {res_json["count"]}")
    if count >= res_json["count"]:
        break
        
lookup = res_json["lookup"]
# Out:
# Page 1: 12 out of 618
# Page 2: 24 out of 618
# Page 3: 36 out of 618
# Page 4: 48 out of 618
# Page 5: 60 out of 618
# Page 6: 72 out of 618
# Page 7: 84 out of 618
# Page 8: 96 out of 618
# Page 9: 108 out of 618
# Page 10: 120 out of 618
# Page 11: 132 out of 618
# Page 12: 144 out of 618
# Page 13: 156 out of 618
# Page 14: 168 out of 618
# Page 15: 180 out of 618
# Page 16: 192 out of 618
# Page 17: 204 out of 618
# Page 18: 216 out of 618
# Page 19: 228 out of 618
# Page 20: 240 out of 618
# Page 21: 252 out of 618
# Page 22: 264 out of 618
# Page 23: 276 out of 618
# Page 24: 288 out of 618
# Page 25: 300 out of 618
# Page 26: 312 out of 618
# Page 27: 324 out of 618
# Page 28: 336 out of 618
# Page 29: 348 out of 618
# Page 30: 360 out of 618
# Page 31: 372 out of 618
# Page 32: 384 out of 618
# Page 33: 396 out of 618
# Page 34: 408 out of 618
# Page 35: 420 out of 618
# Page 36: 432 out of 618
# Page 37: 444 out of 618
# Page 38: 456 out of 618
# Page 39: 468 out of 618
# Page 40: 480 out of 618
# Page 41: 492 out of 618
# Page 42: 504 out of 618
# Page 43: 516 out of 618
# Page 44: 528 out of 618
# Page 45: 540 out of 618
# Page 46: 552 out of 618
# Page 47: 564 out of 618
# Page 48: 576 out of 618
# Page 49: 588 out of 618
# Page 50: 600 out of 618
# Page 51: 612 out of 618
# Page 52: 618 out of 618
# CPU times: total: 438 ms
# Wall time: 3min 12s

# %%
len(items)
# Out:
# 618

# %%
len(lookup)
# Out:
# 9

# %%
lookup.keys()
# Out:
# dict_keys(['Cuisine', 'Borough', 'Neighborhood', 'Accessibility', 'Meal Types', 'Weeks Participating', 'Has Menu', 'Founded By NYC Categories', 'Collections'])

# %%
lookup
# Out:
# {'Cuisine': {'Korean': {'count': 14,
#    'id': '6erFlIpnXYyPL4aBVDJPqe',
#    'label': 'Korean',
#    'slug': 'korean'},
#   'Cuban': {'count': 4,
#    'id': '5SkyKh9qOj7Dd1ynwZ2G0T',
#    'label': 'Cuban',
#    'slug': 'cuban'},
#   'Italian': {'count': 138,
#    'id': '3yTV00jjj7bszV7PNsxlyY',
#    'label': 'Italian',
#    'slug': 'italian'},
#   'Mediterranean': {'count': 45,
#    'id': '60iKLQ1Xjo4BGC2d67e2U7',
#    'label': 'Mediterranean',
#    'slug': 'mediterranean'},
#   'French': {'count': 58,
#    'id': 'hqp75UjDB0fOqwSDraoSt',
#    'label': 'French',
#    'slug': 'french'},
#   'Greek': {'count': 22,
#    'id': '583zqMYoCTy26cFt6xdLI1',
#    'label': 'Greek',
#    'slug': 'greek'},
#   'American (New)': {'count': 121,
#    'id': '2u5r3e6lPwri1BwWU31BbX',
#    'label': 'American (New)',
#    'slug': 'american-new'},
#   'Latin American': {'count': 7,
#    'id': '2hebFB3NMBEI0HT37EqLlf',
#    'label': 'Latin American',
#    'slug': 'latin-american'},
#   'Bars/Cocktails': {'count': 21,
#    'id': '76suAEbHFj4NstgNTJwdHl',
#    'label': 'Bars/Cocktails',
#    'slug': 'barscocktails'},
#   'Soul Food / Southern': {'count': 3,
#    'id': '2ZNSqOO1u1tVur0unoPFAB',
#    'label': 'Soul Food / Southern',
#    'slug': 'soul-food-southern'},
#   'Steakhouse': {'count': 56,
#    'id': '66gAlD86rRShshqk3iBr20',
#    'label': 'Steakhouse',
#    'slug': 'steakhouse'},
#   'Japanese / Sushi': {'count': 44,
#    'id': '5mFtbP7WO79eKYANwxaLva',
#    'label': 'Japanese / Sushi',
#    'slug': 'japanese-sushi'},
#   'Gastropub': {'count': 6,
#    'id': 'VH1UZBVqE1NKi99RSAsPb',
#    'label': 'Gastropub',
#    'slug': 'gastropub'},
#   'Turkish': {'count': 4,
#    'id': '65M2jfg10yM1D6h9Me3SMl',
#    'label': 'Turkish',
#    'slug': 'turkish'},
#   'Indian': {'count': 13,
#    'id': '33Q5TQf50mmGwyj2UcpOt9',
#    'label': 'Indian',
#    'slug': 'indian'},
#   'Austrian': {'count': 2,
#    'id': 'OvkoMyGePU5FT0gQHYsO3',
#    'label': 'Austrian',
#    'slug': 'austrian'},
#   'Eclectic': {'count': 11,
#    'id': '7cuqXb4GlRAkQVX7MM5PW3',
#    'label': 'Eclectic',
#    'slug': 'eclectic'},
#   'Chinese': {'count': 18,
#    'id': '6EOCCoIZAAC8JanUHdxBbY',
#    'label': 'Chinese',
#    'slug': 'chinese'},
#   'Caribbean': {'count': 6,
#    'id': '1BWHyz7T69If6Ilk5NRkwI',
#    'label': 'Caribbean',
#    'slug': 'caribbean'},
#   'Puerto Rican': {'count': 2,
#    'id': '4o33kmYYkg1nzz0fPa05mV',
#    'label': 'Puerto Rican',
#    'slug': 'puerto-rican'},
#   'Spanish': {'count': 12,
#    'id': '5PlxK4HuEPhLkI6zH1BzM1',
#    'label': 'Spanish',
#    'slug': 'spanish'},
#   'Thai': {'count': 19,
#    'id': '1k9HRmtwlqvSdsJuYqb2m2',
#    'label': 'Thai',
#    'slug': 'thai'},
#   'Middle Eastern': {'count': 9,
#    'id': '4grdmRpwni8VDWTsmXNTe1',
#    'label': 'Middle Eastern',
#    'slug': 'middle-eastern'},
#   'Mexican': {'count': 27,
#    'id': '6lrkEqGroUEvKo551SI1oH',
#    'label': 'Mexican',
#    'slug': 'mexican'},
#   'Pizza': {'count': 11,
#    'id': '3mcQRMMO2B9Y784mU7OZdk',
#    'label': 'Pizza',
#    'slug': 'pizza'},
#   'Seafood': {'count': 46,
#    'id': '2nRMOe37rLv8HWZ5A3l4OI',
#    'label': 'Seafood',
#    'slug': 'seafood'},
#   'Vegan': {'count': 3,
#    'id': '7G9WpP5J6ac5cWt1MGhstm',
#    'label': 'Vegan',
#    'slug': 'vegan'},
#   'Vegetarian': {'count': 3,
#    'id': '1bv92IV29i2YetCKbZExlk',
#    'label': 'Vegetarian',
#    'slug': 'vegetarian'},
#   'American (Traditional)': {'count': 29,
#    'id': '5uaUeLgy2Su84FYBKP4LVg',
#    'label': 'American (Traditional)',
#    'slug': 'american-traditional'},
#   'Burgers': {'count': 3,
#    'id': '4XEejlqHMZIid9cvI3370Q',
#    'label': 'Burgers',
#    'slug': 'burgers'},
#   'Barbecue': {'count': 5,
#    'id': '6Xe9xXygaRtxKxF0JaNZFf',
#    'label': 'Barbecue',
#    'slug': 'barbecue'},
#   'Asian Fusion': {'count': 24,
#    'id': '5HxPNXNUlgygLivi9gvQz',
#    'label': 'Asian Fusion',
#    'slug': 'asian-fusion'},
#   'Pan-Asian': {'count': 6,
#    'id': '4IHo2T1oNTEehrwBDHJE23',
#    'label': 'Pan-Asian',
#    'slug': 'pan-asian'},
#   'Southwestern': {'count': 1,
#    'id': '6p3TtvjmqaiCTtS0r5c5S1',
#    'label': 'Southwestern',
#    'slug': 'southwestern'},
#   'Irish': {'count': 7,
#    'id': '3Q8A4wHvG1Gj9w0EUrMz5Q',
#    'label': 'Irish',
#    'slug': 'irish'},
#   'Argentinian': {'count': 3,
#    'id': '4TF9Q2DNmlbrnw91EeM9Da',
#    'label': 'Argentinian',
#    'slug': 'argentinian'},
#   'Ukrainian': {'count': 1,
#    'id': '7D9A5BqDNdreHpMpbyXGGb',
#    'label': 'Ukrainian',
#    'slug': 'ukrainian'},
#   'Modern European': {'count': 1,
#    'id': '1KDJqsoOBssNJFcXTcL4QE',
#    'label': 'Modern European',
#    'slug': 'modern-european'},
#   'Peruvian': {'count': 2,
#    'id': '56MdKhc9szecVGf2AkacOx',
#    'label': 'Peruvian',
#    'slug': 'peruvian'},
#   'Vietnamese': {'count': 4,
#    'id': '7CYKNV83NIZmFkelYeQ7VK',
#    'label': 'Vietnamese',
#    'slug': 'vietnamese'},
#   'Eastern European': {'count': 3,
#    'id': '26eNuSmwdEJMr5UnVVeyae',
#    'label': 'Eastern European',
#    'slug': 'eastern-european'},
#   'British': {'count': 3,
#    'id': '5OKA8ZkrMfaccjbksRfYDW',
#    'label': 'British',
#    'slug': 'british'},
#   'New Zealand': {'count': 1,
#    'id': '11lhwWAzm5FNIsCEPBCn7S',
#    'label': 'New Zealand',
#    'slug': 'new-zealand'},
#   'Taiwanese': {'count': 1,
#    'id': '2ZpO1etbB3DuNC1evhCSvO',
#    'label': 'Taiwanese',
#    'slug': 'taiwanese'},
#   'Belgian': {'count': 1,
#    'id': '7pdzkSXa4AUbT6N2jZEqqJ',
#    'label': 'Belgian',
#    'slug': 'belgian'},
#   'Delicatessen': {'count': 1,
#    'id': 'd7gV1F8AuNdSpGwIqfwwE',
#    'label': 'Delicatessen',
#    'slug': 'delicatessen'},
#   'Continental': {'count': 5,
#    'id': '6Z7jhDkkNpy93UFgyL43KU',
#    'label': 'Continental',
#    'slug': 'continental'},
#   'Brazilian': {'count': 4,
#    'id': '1zolqpZ1JyJbqOeDNgFiNW',
#    'label': 'Brazilian',
#    'slug': 'brazilian'},
#   'Cajun/Creole': {'count': 1,
#    'id': '5zUwQcYy94ZJs7r2eJF8m4',
#    'label': 'Cajun/Creole',
#    'slug': 'cajuncreole'},
#   'Jamaican': {'count': 1,
#    'id': '5HvxVHowtfjvBUKidisRRJ',
#    'label': 'Jamaican',
#    'slug': 'jamaican'},
#   'Hawaiian': {'count': 1,
#    'id': 'taDjvz2zSpfYHzWVEqq0f',
#    'label': 'Hawaiian',
#    'slug': 'hawaiian'},
#   'African': {'count': 1,
#    'id': '6DbkztdPTACBKnINFOk8nW',
#    'label': 'African',
#    'slug': 'african'},
#   'Somali': {'count': 1,
#    'id': '7ktP9GpFxb8Fqnp9AWhwG4',
#    'label': 'Somali',
#    'slug': 'somali'},
#   'Malaysian': {'count': 2,
#    'id': '7BGDq9ZYy99R3SCMRCcv4T',
#    'label': 'Malaysian',
#    'slug': 'malaysian'},
#   'Colombian': {'count': 1,
#    'id': '7tBuZRpdL3H8Kimkf2qiq1',
#    'label': 'Colombian',
#    'slug': 'colombian'},
#   'label': 'Cuisine',
#   'type': 'multiselect',
#   'values': ['Korean',
#    'Cuban',
#    'Italian',
#    'Mediterranean',
#    'French',
#    'Greek',
#    'American (New)',
#    'Latin American',
#    'Bars/Cocktails',
#    'Soul Food / Southern',
#    'Steakhouse',
#    'Japanese / Sushi',
#    'Gastropub',
#    'Turkish',
#    'Indian',
#    'Austrian',
#    'Eclectic',
#    'Chinese',
#    'Caribbean',
#    'Puerto Rican',
#    'Spanish',
#    'Thai',
#    'Middle Eastern',
#    'Mexican',
#    'Pizza',
#    'Seafood',
#    'Vegan',
#    'Vegetarian',
#    'American (Traditional)',
#    'Burgers',
#    'Barbecue',
#    'Asian Fusion',
#    'Pan-Asian',
#    'Southwestern',
#    'Irish',
#    'Argentinian',
#    'Ukrainian',
#    'Modern European',
#    'Peruvian',
#    'Vietnamese',
#    'Eastern European',
#    'British',
#    'New Zealand',
#    'Taiwanese',
#    'Belgian',
#    'Delicatessen',
#    'Continental',
#    'Brazilian',
#    'Cajun/Creole',
#    'Jamaican',
#    'Hawaiian',
#    'African',
#    'Somali',
#    'Malaysian',
#    'Colombian'],
#   'lookupName': 'cuisines'},
#  'Borough': {'Manhattan': {'count': 515,
#    'id': '2NTEba3HJYoWwT28somHcc',
#    'label': 'Manhattan',
#    'slug': 'manhattan'},
#   'Queens': {'count': 31,
#    'id': 'ZLtdnTsUCk7o8gTSHfEgz',
#    'label': 'Queens',
#    'slug': 'queens'},
#   'Staten Island': {'count': 7,
#    'id': '6bZ34HUjaMM5ZDPtc5UR7B',
#    'label': 'Staten Island',
#    'slug': 'staten-island'},
#   'Brooklyn': {'count': 61,
#    'id': '3mTu46dYjcg3mB0MrgP5AU',
#    'label': 'Brooklyn',
#    'slug': 'brooklyn'},
#   'The Bronx': {'count': 4,
#    'id': '3t5Bl1JjoJDRrbv83H7MRS',
#    'label': 'The Bronx',
#    'slug': 'the-bronx'},
#   'label': 'Borough',
#   'type': 'multiselect',
#   'values': ['Manhattan', 'Queens', 'Staten Island', 'Brooklyn', 'The Bronx'],
#   'lookupName': 'borough'},
#  'Neighborhood': {'Lower East Side': {'count': 24,
#    'id': '2qN4P9hfEghwPq6sAjKVjA',
#    'label': 'Lower East Side',
#    'slug': 'lower-east-side'},
#   'Times Square/Theatre District': {'count': 79,
#    'id': '7bC6GrAOzXLvoJAGgTOdzl',
#    'label': 'Times Square/Theatre District',
#    'slug': 'times-squaretheatre-district'},
#   'Midtown West': {'count': 117,
#    'id': '61QB2f7blSGMaKZi1yfOLv',
#    'label': 'Midtown West',
#    'slug': 'midtown-west'},
#   'Midtown': {'count': 74,
#    'id': '1LExA8nslarYIovIHnDo2M',
#    'label': 'Midtown',
#    'slug': 'midtown'},
#   'Murray Hill': {'count': 24,
#    'id': 'XeL6xZNV0BHanR8jbsMuD',
#    'label': 'Murray Hill',
#    'slug': 'murray-hill'},
#   'Kips Bay': {'count': 5,
#    'id': '2jsST2ttADlnGkLYgpa8qI',
#    'label': 'Kips Bay',
#    'slug': 'kips-bay'},
#   'Forest Hills': {'count': 10,
#    'id': '4LtVjfuTm3Z4hb3YiAgAoC',
#    'label': 'Forest Hills',
#    'slug': 'forest-hills'},
#   'Soho': {'count': 26,
#    'id': '52LVi7xKOFZ0XnSF64Qu8W',
#    'label': 'Soho',
#    'slug': 'soho'},
#   'Upper West Side': {'count': 68,
#    'id': '2Fa3xmXblFpWnb67R744VL',
#    'label': 'Upper West Side',
#    'slug': 'upper-west-side'},
#   'Greenwich Village': {'count': 27,
#    'id': '4QangtuYUkuBbu7AU1SRSw',
#    'label': 'Greenwich Village',
#    'slug': 'greenwich-village'},
#   'Bloomfield': {'count': 2,
#    'id': 'FdQvQLO7SSdPV2fHI5X1u',
#    'label': 'Bloomfield',
#    'slug': 'bloomfield'},
#   'Flatiron District': {'count': 40,
#    'id': '7gYVRYq01uHCq2pYtNItT5',
#    'label': 'Flatiron District',
#    'slug': 'flatiron-district'},
#   'The Seaport': {'count': 16,
#    'id': '47OH6Jm8dnAvMDLyGaWzi8',
#    'label': 'The Seaport',
#    'slug': 'the-seaport'},
#   'Lower Manhattan': {'count': 36,
#    'id': '1ULligRcuT6hxnS5zFfWGl',
#    'label': 'Lower Manhattan',
#    'slug': 'lower-manhattan'},
#   'Hells Kitchen': {'count': 41,
#    'id': '1LKdriQXICZbXvssQcQiWT',
#    'label': 'Hells Kitchen',
#    'slug': 'hells-kitchen'},
#   'Park Slope': {'count': 18,
#    'id': '26mZqmCzM8u5znaiAFS3zj',
#    'label': 'Park Slope',
#    'slug': 'park-slope'},
#   'Nomad': {'count': 38,
#    'id': '5dyV0RJlstwK2LoilQkyI1',
#    'label': 'Nomad',
#    'slug': 'nomad'},
#   'Noho': {'count': 18,
#    'id': '6B1WbjxIFRHz6mNzkPW6v5',
#    'label': 'Noho',
#    'slug': 'noho'},
#   'Upper East Side': {'count': 80,
#    'id': '2OrQvTjvaMRREDz0QGlIJU',
#    'label': 'Upper East Side',
#    'slug': 'upper-east-side'},
#   'New Dorp': {'count': 2,
#    'id': '2fCtkg8Q2iIkg6MiZJ3ppW',
#    'label': 'New Dorp',
#    'slug': 'new-dorp'},
#   'West Village': {'count': 40,
#    'id': '1h1CKqntuJBlUEzuzszwKK',
#    'label': 'West Village',
#    'slug': 'west-village'},
#   'Hudson Square': {'count': 4,
#    'id': '5nCtsqHF2mhDULId9HCyxw',
#    'label': 'Hudson Square',
#    'slug': 'hudson-square'},
#   'Chelsea': {'count': 51,
#    'id': '34JJy3vOrcZxehSGau7gq9',
#    'label': 'Chelsea',
#    'slug': 'chelsea'},
#   'Herald Square': {'count': 14,
#    'id': '1Jj5rhV8eN7AYPmY4n2b5q',
#    'label': 'Herald Square',
#    'slug': 'herald-square'},
#   'East Village': {'count': 50,
#    'id': '6bUnDkwrgIUyGxGWohSJGi',
#    'label': 'East Village',
#    'slug': 'east-village'},
#   'Little Neck': {'count': 2,
#    'id': '1QSHOPOQ3AMbfqBqmrTghy',
#    'label': 'Little Neck',
#    'slug': 'little-neck'},
#   'Meatpacking District': {'count': 8,
#    'id': '5fWzIA7KWA59Q5aCB5GnbC',
#    'label': 'Meatpacking District',
#    'slug': 'meatpacking-district'},
#   'Midtown East': {'count': 99,
#    'id': '1yrv3RQN0fXSCHvHm82nHN',
#    'label': 'Midtown East',
#    'slug': 'midtown-east'},
#   'Astoria': {'count': 12,
#    'id': '4DCR0vMxDtZFWcVOI0809b',
#    'label': 'Astoria',
#    'slug': 'astoria'},
#   'Tribeca': {'count': 16,
#    'id': 'E3FdzsWjyFbr6cyt75FS6',
#    'label': 'Tribeca',
#    'slug': 'tribeca'},
#   'Long Island City': {'count': 10,
#    'id': '2n7urs7UPA2wOWpRm1uaf1',
#    'label': 'Long Island City',
#    'slug': 'long-island-city'},
#   'Nolita': {'count': 14,
#    'id': '7FHG8RkEFefLGuEea4yHCO',
#    'label': 'Nolita',
#    'slug': 'nolita'},
#   'Williamsburg': {'count': 42,
#    'id': 'jqTjGdFa7iLRDJ7Fy5BM0',
#    'label': 'Williamsburg',
#    'slug': 'williamsburg'},
#   'Gramercy': {'count': 34,
#    'id': '6vN5GObLgLffMUPwv5UZu1',
#    'label': 'Gramercy',
#    'slug': 'gramercy'},
#   'Garment District': {'count': 14,
#    'id': '23Ol3QxkVOJpbQeL8GPP2P',
#    'label': 'Garment District',
#    'slug': 'garment-district'},
#   'Bay Ridge': {'count': 8,
#    'id': '6HK93lYIFgNeFGIFzQQRCl',
#    'label': 'Bay Ridge',
#    'slug': 'bay-ridge'},
#   'Prospect Heights': {'count': 8,
#    'id': '3GZrUyLQwjWgwYbLi9v98i',
#    'label': 'Prospect Heights',
#    'slug': 'prospect-heights'},
#   'Greenpoint': {'count': 4,
#    'id': '3Lqy1ED6Ht7eXqmSAkdpoy',
#    'label': 'Greenpoint',
#    'slug': 'greenpoint'},
#   'Battery Park City': {'count': 10,
#    'id': '6KgmBWhznEz7Rcy2C5tYgL',
#    'label': 'Battery Park City',
#    'slug': 'battery-park-city'},
#   'Harlem': {'count': 20,
#    'id': '4vY3o5tV1zIHNE8zuDH8ht',
#    'label': 'Harlem',
#    'slug': 'harlem'},
#   'Mott Haven': {'count': 2,
#    'id': '5bHTg9EW6XuXmpLYeL79FT',
#    'label': 'Mott Haven',
#    'slug': 'mott-haven'},
#   'Dumbo': {'count': 4,
#    'id': '5WfEIg9alXNmUJsl7CG3hs',
#    'label': 'Dumbo',
#    'slug': 'dumbo'},
#   'Carroll Gardens': {'count': 4,
#    'id': '3OrsgsYkXbHfmVRJgehI35',
#    'label': 'Carroll Gardens',
#    'slug': 'carroll-gardens'},
#   'Little Italy': {'count': 4,
#    'id': '6WWAScC9CIjCCR6jgrExx3',
#    'label': 'Little Italy',
#    'slug': 'little-italy'},
#   'Coney Island': {'count': 2,
#    'id': 'fgvIVvpt2SxAvJgAZm8Yw',
#    'label': 'Coney Island',
#    'slug': 'coney-island'},
#   'Riverdale': {'count': 2,
#    'id': '2fgOX96OfhpO3WtNAdPl5r',
#    'label': 'Riverdale',
#    'slug': 'riverdale'},
#   'New Hyde Park': {'count': 2,
#    'id': '5ZUFjiqujchswsCDEwlYnW',
#    'label': 'New Hyde Park',
#    'slug': 'new-hyde-park'},
#   'South Slope': {'count': 4,
#    'id': '5DiqiooihIrMNcJfTsr3ck',
#    'label': 'South Slope',
#    'slug': 'south-slope'},
#   'Boerum Hill': {'count': 10,
#    'id': '1AH9V2IzLruG8F4diHBzRf',
#    'label': 'Boerum Hill',
#    'slug': 'boerum-hill'},
#   'Alphabet City': {'count': 1,
#    'id': '7HCNMQRkqk9WeEdElXAVRF',
#    'label': 'Alphabet City',
#    'slug': 'alphabet-city'},
#   'Central Park': {'count': 4,
#    'id': '211skuRtHXTL5QiSLLEvgm',
#    'label': 'Central Park',
#    'slug': 'central-park'},
#   'Flushing': {'count': 8,
#    'id': '1dPHBAhCeLrOjYuXWhgEFb',
#    'label': 'Flushing',
#    'slug': 'flushing'},
#   'Rosebank': {'count': 2,
#    'id': '579qWajkpImw6Dkdk56p6o',
#    'label': 'Rosebank',
#    'slug': 'rosebank'},
#   'Belmont': {'count': 2,
#    'id': '4AUp3rWNx0xxVMLoKIq3kp',
#    'label': 'Belmont',
#    'slug': 'belmont'},
#   'Union Square': {'count': 22,
#    'id': '7BxqcAYVYoj33m3iwvkwqa',
#    'label': 'Union Square',
#    'slug': 'union-square'},
#   'St. George': {'count': 2,
#    'id': '1fVuJQBPkksFDDc37i0SIR',
#    'label': 'St. George',
#    'slug': 'st-george'},
#   'Brooklyn Heights': {'count': 4,
#    'id': 'BrVmeYRTAoLVb6jwQz6SQ',
#    'label': 'Brooklyn Heights',
#    'slug': 'brooklyn-heights'},
#   'Hudson Yards': {'count': 14,
#    'id': '2KEl3016ktlIWbRHkhvCop',
#    'label': 'Hudson Yards',
#    'slug': 'hudson-yards'},
#   'Jackson Heights': {'count': 5,
#    'id': '749ggaz7Xy1RncGKQfhhEM',
#    'label': 'Jackson Heights',
#    'slug': 'jackson-heights'},
#   'Washington Heights': {'count': 4,
#    'id': '5mO0B8omv4Jg7RWBO9ivAQ',
#    'label': 'Washington Heights',
#    'slug': 'washington-heights'},
#   'Hamilton Heights': {'count': 4,
#    'id': '3eqvm5n51tIaN4uBlQphPh',
#    'label': 'Hamilton Heights',
#    'slug': 'hamilton-heights'},
#   'Bayside': {'count': 6,
#    'id': '41UtPfm5Xca1FVJWOEJe5w',
#    'label': 'Bayside',
#    'slug': 'bayside'},
#   'Woodhaven': {'count': 2,
#    'id': '1oRGiwPcrd2TK4xreBMMiU',
#    'label': 'Woodhaven',
#    'slug': 'woodhaven'},
#   'Red Hook': {'count': 2,
#    'id': '15O7B8ROpOFDS9DyxU0buJ',
#    'label': 'Red Hook',
#    'slug': 'red-hook'},
#   'Clinton Hill': {'count': 2,
#    'id': '6S1Wdv1BhLyWGjqPUK1d6l',
#    'label': 'Clinton Hill',
#    'slug': 'clinton-hill'},
#   'Koreatown': {'count': 6,
#    'id': '6ih6v4gaf3RRw2WqVEzww2',
#    'label': 'Koreatown',
#    'slug': 'koreatown'},
#   'East Harlem': {'count': 4,
#    'id': 'lkb2nfAdErSztMlRJjE6n',
#    'label': 'East Harlem',
#    'slug': 'east-harlem'},
#   'Flatlands': {'count': 2,
#    'id': '62qagzGg0M7YQrZzLdv5dl',
#    'label': 'Flatlands',
#    'slug': 'flatlands'},
#   'Jamaica': {'count': 2,
#    'id': '56LGR0FYDmfpR3HP5CjiJK',
#    'label': 'Jamaica',
#    'slug': 'jamaica'},
#   'Prospect Lefferts Gardens': {'count': 2,
#    'id': '4CmhGvHyl0RxsqLgEXrmFW',
#    'label': 'Prospect Lefferts Gardens',
#    'slug': 'prospect-lefferts-gardens'},
#   'Woodstock': {'count': 2,
#    'id': '27qMPhv3k7y867ktrjKhki',
#    'label': 'Woodstock',
#    'slug': 'woodstock'},
#   'Cobble Hill': {'count': 4,
#    'id': '1JKy9cQVz6BX5o7qSO5W1E',
#    'label': 'Cobble Hill',
#    'slug': 'cobble-hill'},
#   'Tompkinsville': {'count': 2,
#    'id': '4qNRfz22WItCCh4t6UEA5p',
#    'label': 'Tompkinsville',
#    'slug': 'tompkinsville'},
#   'Todt Hill': {'count': 2,
#    'id': '7Ylxe39vQEzjLJOGB6K9m',
#    'label': 'Todt Hill',
#    'slug': 'todt-hill'},
#   'Elmhurst': {'count': 2,
#    'id': '2Ly0gcQhSDKTvu0Aup93Gg',
#    'label': 'Elmhurst',
#    'slug': 'elmhurst'},
#   'East Elmhurst': {'count': 2,
#    'id': '7LI6820itCXFFCZv3iurPu',
#    'label': 'East Elmhurst',
#    'slug': 'east-elmhurst'},
#   'West Brighton': {'count': 2,
#    'id': '3Q1FonXdHYtLtrkwNnBLE2',
#    'label': 'West Brighton',
#    'slug': 'west-brighton'},
#   'Downtown Brooklyn': {'count': 2,
#    'id': '1OIRg3CypIeCorXfFJ5DNP',
#    'label': 'Downtown Brooklyn',
#    'slug': 'downtown-brooklyn'},
#   'Morningside Heights': {'count': 2,
#    'id': '2ovKDGD5Sy8SpkSyYcp7CH',
#    'label': 'Morningside Heights',
#    'slug': 'morningside-heights'},
#   'label': 'Neighborhood',
#   'type': 'multiselect',
#   'values': ['Lower East Side',
#    'Times Square/Theatre District',
#    'Midtown West',
#    'Midtown',
#    'Murray Hill',
#    'Kips Bay',
#    'Forest Hills',
#    'Soho',
#    'Upper West Side',
#    'Greenwich Village',
#    'Bloomfield',
#    'Flatiron District',
#    'The Seaport',
#    'Lower Manhattan',
#    'Hells Kitchen',
#    'Park Slope',
#    'Nomad',
#    'Noho',
#    'Upper East Side',
#    'New Dorp',
#    'West Village',
#    'Hudson Square',
#    'Chelsea',
#    'Herald Square',
#    'East Village',
#    'Little Neck',
#    'Meatpacking District',
#    'Midtown East',
#    'Astoria',
#    'Tribeca',
#    'Long Island City',
#    'Nolita',
#    'Williamsburg',
#    'Gramercy',
#    'Garment District',
#    'Bay Ridge',
#    'Prospect Heights',
#    'Greenpoint',
#    'Battery Park City',
#    'Harlem',
#    'Mott Haven',
#    'Dumbo',
#    'Carroll Gardens',
#    'Little Italy',
#    'Coney Island',
#    'Riverdale',
#    'New Hyde Park',
#    'South Slope',
#    'Boerum Hill',
#    'Alphabet City',
#    'Central Park',
#    'Flushing',
#    'Rosebank',
#    'Belmont',
#    'Union Square',
#    'St. George',
#    'Brooklyn Heights',
#    'Hudson Yards',
#    'Jackson Heights',
#    'Washington Heights',
#    'Hamilton Heights',
#    'Bayside',
#    'Woodhaven',
#    'Red Hook',
#    'Clinton Hill',
#    'Koreatown',
#    'East Harlem',
#    'Flatlands',
#    'Jamaica',
#    'Prospect Lefferts Gardens',
#    'Woodstock',
#    'Cobble Hill',
#    'Tompkinsville',
#    'Todt Hill',
#    'Elmhurst',
#    'East Elmhurst',
#    'West Brighton',
#    'Downtown Brooklyn',
#    'Morningside Heights'],
#   'lookupName': 'neighborhood'},
#  'Accessibility': {'Wheelchair Accessible': {'count': 568,
#    'id': '3UnxXQdjBymIv5gWofDT00',
#    'label': 'Wheelchair Accessible',
#    'slug': 'wheelchair-accessible'},
#   'Large Print': {'count': 179,
#    'id': '7F66X8cEpvhXvFRLuqQuep',
#    'label': 'Large Print',
#    'slug': 'large-print'},
#   'Braille': {'count': 38,
#    'id': '1w4zeGXXQ31MWeV2zYKqoQ',
#    'label': 'Braille',
#    'slug': 'braille'},
#   'Open and/or Closed Captioned': {'count': 1,
#    'id': '2EWQakO37Rm88FjjOh1CQ1',
#    'label': 'Open and/or Closed Captioned',
#    'slug': 'open-andor-closed-captioned'},
#   'Volume Control Telephone': {'count': 1,
#    'id': 'ZUO4Ezfzu7LSowc8kPWeq',
#    'label': 'Volume Control Telephone',
#    'slug': 'volume-control-telephone'},
#   'Assistive Listening System': {'count': 1,
#    'id': '3k1gFy7gmkd6G1T6McTea4',
#    'label': 'Assistive Listening System',
#    'slug': 'assistive-listening-system'},
#   'label': 'Accessibility',
#   'type': 'multiselect',
#   'values': ['Wheelchair Accessible',
#    'Large Print',
#    'Braille',
#    'Open and/or Closed Captioned',
#    'Volume Control Telephone',
#    'Assistive Listening System'],
#   'lookupName': 'accessibility'},
#  'Meal Types': {'$45 Dinner Price': {'count': 248},
#   '$30 Sunday Lunch/Brunch Price': {'count': 125},
#   '$45 Sunday Dinner Price': {'count': 195},
#   '$30 Lunch Price': {'count': 250},
#   '$60 Dinner Price': {'count': 305},
#   '$60 Sunday Dinner Price': {'count': 225},
#   '$45 Lunch Price': {'count': 113},
#   '$45 Sunday Lunch/Brunch Price': {'count': 80},
#   '$60 Sunday Lunch/Brunch Price': {'count': 15},
#   '$30 Dinner Price': {'count': 23},
#   '$30 Sunday Dinner Price': {'count': 22},
#   '$60 Lunch Price': {'count': 22},
#   'label': 'Meal Types',
#   'type': 'multiselect',
#   'values': ['$45 Dinner Price',
#    '$30 Sunday Lunch/Brunch Price',
#    '$45 Sunday Dinner Price',
#    '$30 Lunch Price',
#    '$60 Dinner Price',
#    '$60 Sunday Dinner Price',
#    '$45 Lunch Price',
#    '$45 Sunday Lunch/Brunch Price',
#    '$60 Sunday Lunch/Brunch Price',
#    '$30 Dinner Price',
#    '$30 Sunday Dinner Price',
#    '$60 Lunch Price'],
#   'lookupName': 'mealTypes'},
#  'Weeks Participating': {'Week 1 (July 21 - July 27)': {'count': 612},
#   'Week 2 (July 28 - Aug 3)': {'count': 616},
#   'Week 3 (Aug 4 - Aug 10)': {'count': 601},
#   'Week 4 (Aug 11 - Aug 17)': {'count': 594},
#   'Week 5 (Aug 18 - Aug 24)': {'count': 443},
#   'Week 6 (Aug 25 - Aug 31)': {'count': 427},
#   'label': 'Weeks Participating',
#   'type': 'multiselect',
#   'values': ['Week 1 (July 21 - July 27)',
#    'Week 2 (July 28 - Aug 3)',
#    'Week 3 (Aug 4 - Aug 10)',
#    'Week 4 (Aug 11 - Aug 17)',
#    'Week 5 (Aug 18 - Aug 24)',
#    'Week 6 (Aug 25 - Aug 31)'],
#   'lookupName': 'inclusionWeeks'},
#  'Has Menu': {'true': {'count': 440},
#   'false': {'count': 178},
#   'label': 'Has Menu',
#   'type': 'toggle',
#   'values': ['true', 'false'],
#   'lookupName': 'hasMenu'},
#  'Founded By NYC Categories': {'Restaurant Signature Dish': {'count': 90,
#    'id': '6V5rSjb80DVddiSy6im5DR',
#    'label': 'Restaurant Signature Dish',
#    'slug': 'rw-fbnyc-restaurant-signature-dish'},
#   'Restaurant Signature Cocktail': {'count': 48,
#    'id': '3c29wDd7x4x6ArYj8gVfdR',
#    'label': 'Restaurant Signature Cocktail',
#    'slug': 'rw-fbnyc-restaurant-signature-cocktail'},
#   '$16.25 Cocktail': {'count': 81,
#    'id': '6qWcFJDodv5spn11ZBjRS0',
#    'label': '$16.25 Cocktail',
#    'slug': 'rw-fbnyc-1625-cocktail'},
#   '$16.25 Dish': {'count': 23,
#    'id': '2GebBqrL06NBXwiQmQ5fsv',
#    'label': '$16.25 Dish',
#    'slug': 'rw-fbnyc-1625-dish'},
#   'NYC Original Cocktail': {'count': 31,
#    'id': '6xqiypVjUTJWhWijgbKeTu',
#    'label': 'NYC Original Cocktail',
#    'slug': 'rw-fbnyc-nyc-original-cocktail'},
#   'NYC Original Dish': {'count': 52,
#    'id': '4rdEWIgrDKFsGqJWZ45v9B',
#    'label': 'NYC Original Dish',
#    'slug': 'rw-fbnyc-nyc-original-dish'},
#   'label': 'Founded By NYC Categories',
#   'type': 'multiselect',
#   'values': ['Restaurant Signature Dish',
#    'Restaurant Signature Cocktail',
#    '$16.25 Cocktail',
#    '$16.25 Dish',
#    'NYC Original Cocktail',
#    'NYC Original Dish'],
#   'lookupName': 'rwFbnycCategories'},
#  'Collections': {'classic-restaurants': {'count': 9},
#   'around-the-boroughs': {'count': 13},
#   'hidden-gems': {'count': 10},
#   'date-night': {'count': 12},
#   'for-the-foodies': {'count': 9},
#   'dress-for-the-occasion': {'count': 13},
#   'summer-vibes': {'count': 9},
#   'celebrity-chefs': {'count': 8},
#   'label': 'Collections',
#   'type': 'multiselect',
#   'values': ['classic-restaurants',
#    'around-the-boroughs',
#    'hidden-gems',
#    'date-night',
#    'for-the-foodies',
#    'dress-for-the-occasion',
#    'summer-vibes',
#    'celebrity-chefs'],
#   'lookupName': 'collections'}}

# %%
restaurant_data_df = pd.DataFrame(items)
restaurant_data_df["rest_week_site_url"] = "https://www.nyctourism.com/restaurant-week/"+restaurant_data_df["slug"]
restaurant_data_df["image_url"] = restaurant_data_df["image"].map(lambda x: f'https:{x["url"]}' if x["url"] else None)
restaurant_data_df
# Out:
#        borough                   neighborhood primaryCategory  \
# 0    Manhattan                Lower East Side     Restaurants
# 1    Manhattan  Times Square/Theatre District     Restaurants
# 2    Manhattan  Times Square/Theatre District     Restaurants
# 3    Manhattan                    Murray Hill     Restaurants
# 4       Queens                   Forest Hills     Restaurants
# ..         ...                            ...             ...
# 613  Manhattan                         Harlem       Nightlife
# 614  Manhattan                        Chelsea     Restaurants
# 615  Manhattan                Upper East Side     Restaurants
# 616  Manhattan                Upper West Side     Restaurants
# 617  Manhattan                Upper West Side     Restaurants
#
#                    primaryLocation  \
# 0                  Lower East Side
# 1    Times Square/Theatre District
# 2    Times Square/Theatre District
# 3                      Murray Hill
# 4                     Forest Hills
# ..                             ...
# 613                         Harlem
# 614                        Chelsea
# 615                Upper East Side
# 616                Upper West Side
# 617                Upper West Side
#
#                                             ctaButtons  \
# 0    {'primary': {'label': {'presale': False, 'gene...
# 1    {'primary': {'label': {'presale': False, 'gene...
# 2    {'primary': {'label': {'presale': False, 'gene...
# 3    {'primary': {'label': {'presale': False, 'gene...
# 4    {'primary': {'label': {'presale': False, 'gene...
# ..                                                 ...
# 613  {'primary': {'label': {'presale': False, 'gene...
# 614  {'primary': {'label': {'presale': False, 'gene...
# 615  {'primary': {'label': {'presale': False, 'gene...
# 616  {'primary': {'label': {'presale': False, 'gene...
# 617  {'primary': {'label': {'presale': False, 'gene...
#
#                                          tags                      shortTitle  \
# 0                   [Korean, Lower East Side]                         Sae Ron
# 1      [Cuban, Times Square/Theatre District]                   Victor's Cafe
# 2    [Italian, Times Square/Theatre District]                        AperiBar
# 3                [Mediterranean, Murray Hill]                        Leonetta
# 4                     [Italian, Forest Hills]                    Tuscan Hills
# ..                                        ...                             ...
# 613                          [French, Harlem]                        Barawine
# 614                           [Thai, Chelsea]                        Wan Waan
# 615                  [Greek, Upper East Side]                Yefsi Estiatorio
# 616                 [French, Upper West Side]        Amélie - Upper West Side
# 617              [Pan-Asian, Upper West Side]  Pig and Khao - Upper West Side
#
#                              slug  \
# 0                         sae-ron
# 1                    victors-cafe
# 2                        aperibar
# 3                        leonetta
# 4                    tuscan-hills
# ..                            ...
# 613               barawine-harlem
# 614                      wan-waan
# 615              yefsi-estiatorio
# 616        amelie-upper-west-side
# 617  pig-and-khao-upper-west-side
#
#                                                  image  \
# 0    {'url': '//images.ctfassets.net/1aemqu6a6t65/1...
# 1    {'url': '//images.ctfassets.net/1aemqu6a6t65/2...
# 2    {'url': '//images.ctfassets.net/1aemqu6a6t65/1...
# 3    {'url': '//images.ctfassets.net/1aemqu6a6t65/4...
# 4    {'url': '//images.ctfassets.net/1aemqu6a6t65/2...
# ..                                                 ...
# 613                             {'url': '', 'alt': ''}
# 614                             {'url': '', 'alt': ''}
# 615                             {'url': '', 'alt': ''}
# 616                             {'url': '', 'alt': ''}
# 617                             {'url': '', 'alt': ''}
#
#                                                summary  \
# 0    Sae Ron is a modern Korean kitchen dedicated t...
# 1    Victor’s, in the Theatre District, has been a ...
# 2    This chic restaurant and cocktail bar serves u...
# 3    Bringing Mediterranean warmth to Murray Hill a...
# 4    Tuscan dishes such as the house specialty, cac...
# ..                                                 ...
# 613  This chic wine bar—overseen by Fabrice Warin, ...
# 614  The team at Wan Waan, a Thai restaurant in the...
# 615  Yefsi Estiatorio, a Greek restaurant on Manhat...
# 616  "La Petite Amélie" is smaller and more intimat...
# 617  Pig and Khao is inspired by chef Leah Cohen's ...
#
#                              website menuFileUrl collections  \
# 0          https://www.saeronnyc.com                      []
# 1            https://victorscafe.com                      []
# 2           https://www.aperibar.com                      []
# 3        https://www.leonettanyc.com                      []
# 4     https://www.tuscanhillsnyc.com                      []
# ..                               ...         ...         ...
# 613         https://www.barawine.com                      []
# 614               https://wannyc.com                      []
# 615   http://www.yefsiestiatorio.com                      []
# 616  https://www.amelieupperwest.com                      []
# 617   https://www.pigandkhao.com/uws                      []
#
#                                              mealTypes  \
# 0                                   [$45 Dinner Price]
# 1    [$45 Dinner Price, $30 Sunday Lunch/Brunch Pri...
# 2                                   [$45 Dinner Price]
# 3     [$30 Lunch Price, $30 Sunday Lunch/Brunch Price]
# 4    [$30 Lunch Price, $45 Dinner Price, $30 Sunday...
# ..                                                 ...
# 613  [$45 Lunch Price, $45 Dinner Price, $30 Sunday...
# 614  [$30 Lunch Price, $45 Dinner Price, $45 Sunday...
# 615                [$30 Lunch Price, $45 Dinner Price]
# 616        [$45 Dinner Price, $45 Sunday Dinner Price]
# 617  [$60 Dinner Price, $30 Sunday Lunch/Brunch Pri...
#
#                                restaurantInclusionWeek  \
# 0    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 1    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 2    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 3    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 4    [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# ..                                                 ...
# 613  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 614  [Week 2 (July 28 - Aug 3), Week 3 (Aug 4 - Aug...
# 615  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 616  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
# 617  [Week 1 (July 21 - July 27), Week 2 (July 28 -...
#
#                                              ecommerce  \
# 0                                                  NaN
# 1    {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 2    {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 613  {'title': 'OpenTable', 'partnerName': 'OpenTab...
# 614                                                NaN
# 615                                                NaN
# 616                                                NaN
# 617  {'title': 'OpenTable', 'partnerName': 'OpenTab...
#
#                                     rest_week_site_url  \
# 0    https://www.nyctourism.com/restaurant-week/sae...
# 1    https://www.nyctourism.com/restaurant-week/vic...
# 2    https://www.nyctourism.com/restaurant-week/ape...
# 3    https://www.nyctourism.com/restaurant-week/leo...
# 4    https://www.nyctourism.com/restaurant-week/tus...
# ..                                                 ...
# 613  https://www.nyctourism.com/restaurant-week/bar...
# 614  https://www.nyctourism.com/restaurant-week/wan...
# 615  https://www.nyctourism.com/restaurant-week/yef...
# 616  https://www.nyctourism.com/restaurant-week/ame...
# 617  https://www.nyctourism.com/restaurant-week/pig...
#
#                                              image_url
# 0    https://images.ctfassets.net/1aemqu6a6t65/1G7R...
# 1    https://images.ctfassets.net/1aemqu6a6t65/2DMb...
# 2    https://images.ctfassets.net/1aemqu6a6t65/1TiS...
# 3    https://images.ctfassets.net/1aemqu6a6t65/4eyN...
# 4    https://images.ctfassets.net/1aemqu6a6t65/24Hz...
# ..                                                 ...
# 613                                               None
# 614                                               None
# 615                                               None
# 616                                               None
# 617                                               None
#
# [618 rows x 18 columns]

# %%
restaurant_data_df.to_excel("rw_resturants_2025-07_v3.xlsx", index=False)
